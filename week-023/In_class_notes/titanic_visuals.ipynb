# %%
import pandas as pd
from matplotlib import pyplot as plt

titanic = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# y-axis: 0, 1 - people who survived vs. didn't
# x - passenger id?

# %%
# Create visual of survivors who are male and female
# Create a visual of survivors based on class
# Create visual of people who survived vs didn't

survived = titanic.loc[titanic['Survived'] == 1]
sex = survived['Sex'].value_counts()
sex
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
survive = titanic['Survived'].value_counts()

axes = survive.plot.barh(y='Survived', color='purple', title='Died vs. Survived')

# %%
sex.plot.bar(x='Sex', y='Survived')
plt.title('Survivors')
plt.xlabel('Sex')
plt.ylabel('Number of Survivors')
# Out:
# Text(0, 0.5, 'Number of Survivors')

# %%
survived = titanic.loc[titanic['Survived'] == 1]
pclass = survived['Pclass'].value_counts()

pclass
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
# For Matplotlib, use this function to format percent in pie
def func(pct):
  return '{:1.1f}%'.format(pct)

# For pandas plot, use autopct
pclass.plot.pie(x='Pclass', title='Survivors Based off of Class', autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Survivors Based off of Class'}, ylabel='Pclass'>

# %%
plt.scatter(titanic['Pclass'], titanic['Survived'].value_counts())

# %%
plt.bar(y, height=y, align='center', alpha=0.5)
plt.xticks(y, x)
plt.ylabel('Survived')
plt.xlabel('Sex')
plt.title('Male vs Female Survivors')

plt.show()
