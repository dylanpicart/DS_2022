# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots() # Create a figure containing a single Axes
# fig and ax are objects we create to store the variables of the figures and axes in subplot
# Figure is a wrapper for the axes

# %%
fig1 = plt.figure()

# fig.clear clears axes

# %%
fig, ax = plt.subplots(2, 2)

# %%
fig1.clear()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

# %% [markdown]
# # Figure

# %%
fig = plt.figure()

# %%
fig.suptitle('Lemons', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Lemons')

# %%
fig

# %% [markdown]
# # Axes

# %%
fig.add_axes([0, 0, 1, 1]) # left, bottom, width, height
# Out:
# <Axes:>

# %%
fig

# %% [markdown]
# # Plot

# %%
fig2 = plt.figure()
ax2 = fig2.add_axes([0, 0, 1, 1])
ax5 = 
fig2

# %%
# Out:
# '0.30'
