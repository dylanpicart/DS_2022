# %% [markdown]
# # Data and How to Source It
#
# ## What is an Application Programming Interface (API)?
#
# Kind of like a bridge to connect two programs.
#
# Allows us to build an intermediary between the DataBase and user.

# %% [markdown]
# Language of the Internet: HTTP - Hypertext Transfer Protocol
#
# You make a request to a server and it goes through an intermediary (DNS - Domain Naming System; acts like a phonebook provided by internet service provider). Matches request (ie: google.com) with IP address
# Requests are typically get requests. Get the HTNL, CSS, & JavaScript domain of the IP
#
# As Data Scientists, we will be making a direct requests to the server

# %% [markdown]
# ## How do we make HTTPS requests in Python?

# %%
import requests

# %%
# Create a special object to directly get the api
r = requests.get('https://api.github.com/events')

# %%
# Attribute of r object - contains raw text from our request - it's typecast into a string
r.text

# %%
# To get a true representation of the object
# This is a JSON object (JavaScript Object Notation)
# A way of storing data in the web
# These are key-value pairings, similarly to Python dictionaries
# Returns a list, therefore we can actually index this list; let's try [0]
r.json()[0]

# type(r.json()[0])
# UTF-8 is the standard code
# Out:
# {'id': '20860773825',
#  'type': 'PushEvent',
#  'actor': {'id': 41898282,
#   'login': 'github-actions[bot]',
#   'display_login': 'github-actions',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/github-actions[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#  'repo': {'id': 363744144,
#   'name': 'Sytehk/icctest',
#   'url': 'https://api.github.com/repos/Sytehk/icctest'},
#  'payload': {'push_id': 9410344934,
#   'size': 1,
#   'distinct_size': 1,
#   'ref': 'refs/heads/master',
#   'head': '0ad4c9353044ab5c9e465476429b23dac3424398',
#   'before': '0a31d7f6159e195c69bf0dafedccaee1180331fc',
#   'commits': [{'sha': '0ad4c9353044ab5c9e465476429b23dac3424398',
#     'author': {'email': 'jaytechx@gmail.com', 'name': 'JayT'},
#     'message': 'feat: 🙈 auto commit',
#     'distinct': True,
#     'url': 'https://api.github.com/repos/Sytehk/icctest/commits/0ad4c9353044ab5c9e465476429b23dac3424398'}]},
#  'public': True,
#  'created_at': '2022-03-21T22:21:36Z'}

# %%
# Let's use a different example
r = requests.get('https://data.cityofnewyork.us/resource/f9bf-2cp4.json')

# %%
r.json()
# Out:
# [{'dbn': '01M292',
#   'school_name': 'HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES',
#   'num_of_sat_test_takers': '29',
#   'sat_critical_reading_avg_score': '355',
#   'sat_math_avg_score': '404',
#   'sat_writing_avg_score': '363'},
#  {'dbn': '01M448',
#   'school_name': 'UNIVERSITY NEIGHBORHOOD HIGH SCHOOL',
#   'num_of_sat_test_takers': '91',
#   'sat_critical_reading_avg_score': '383',
#   'sat_math_avg_score': '423',
#   'sat_writing_avg_score': '366'},
#  {'dbn': '01M450',
#   'school_name': 'EAST SIDE COMMUNITY SCHOOL',
#   'num_of_sat_test_takers': '70',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '402',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '01M458',
#   'school_name': 'FORSYTH SATELLITE ACADEMY',
#   'num_of_sat_test_takers': '7',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '401',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '01M509',
#   'school_name': 'MARTA VALLE HIGH SCHOOL',
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '390',
#   'sat_math_avg_score': '433',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '01M515',
#   'school_name': 'LOWER EAST SIDE PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '112',
#   'sat_critical_reading_avg_score': '332',
#   'sat_math_avg_score': '557',
#   'sat_writing_avg_score': '316'},
#  {'dbn': '01M539',
#   'school_name': 'NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND MATH HIGH SCHOOL',
#   'num_of_sat_test_takers': '159',
#   'sat_critical_reading_avg_score': '522',
#   'sat_math_avg_score': '574',
#   'sat_writing_avg_score': '525'},
#  {'dbn': '01M650',
#   'school_name': 'CASCADES HIGH SCHOOL',
#   'num_of_sat_test_takers': '18',
#   'sat_critical_reading_avg_score': '417',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '01M696',
#   'school_name': 'BARD HIGH SCHOOL EARLY COLLEGE',
#   'num_of_sat_test_takers': '130',
#   'sat_critical_reading_avg_score': '624',
#   'sat_math_avg_score': '604',
#   'sat_writing_avg_score': '628'},
#  {'dbn': '02M047',
#   'school_name': '47 THE AMERICAN SIGN LANGUAGE AND ENGLISH SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '16',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '387'},
#  {'dbn': '02M288',
#   'school_name': 'FOOD AND FINANCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '409',
#   'sat_math_avg_score': '393',
#   'sat_writing_avg_score': '392'},
#  {'dbn': '02M294',
#   'school_name': 'ESSEX STREET ACADEMY',
#   'num_of_sat_test_takers': '53',
#   'sat_critical_reading_avg_score': '394',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '378'},
#  {'dbn': '02M296',
#   'school_name': 'HIGH SCHOOL OF HOSPITALITY MANAGEMENT',
#   'num_of_sat_test_takers': '58',
#   'sat_critical_reading_avg_score': '374',
#   'sat_math_avg_score': '375',
#   'sat_writing_avg_score': '362'},
#  {'dbn': '02M298',
#   'school_name': 'PACE HIGH SCHOOL',
#   'num_of_sat_test_takers': '85',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '438',
#   'sat_writing_avg_score': '432'},
#  {'dbn': '02M300',
#   'school_name': 'URBAN ASSEMBLY SCHOOL OF DESIGN AND CONSTRUCTION, THE',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '449',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '02M303',
#   'school_name': 'FACING HISTORY SCHOOL, THE',
#   'num_of_sat_test_takers': '76',
#   'sat_critical_reading_avg_score': '353',
#   'sat_math_avg_score': '358',
#   'sat_writing_avg_score': '340'},
#  {'dbn': '02M305',
#   'school_name': 'URBAN ASSEMBLY ACADEMY OF GOVERNMENT AND LAW, THE',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '375',
#   'sat_math_avg_score': '388',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '02M308',
#   'school_name': 'LOWER MANHATTAN ARTS ACADEMY',
#   'num_of_sat_test_takers': '40',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '392',
#   'sat_writing_avg_score': '405'},
#  {'dbn': '02M313',
#   'school_name': 'JAMES BALDWIN SCHOOL, THE: A SCHOOL FOR EXPEDITIONARY LEARNING',
#   'num_of_sat_test_takers': '69',
#   'sat_critical_reading_avg_score': '408',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '390'},
#  {'dbn': '02M316',
#   'school_name': 'URBAN ASSEMBLY SCHOOL OF BUSINESS FOR YOUNG WOMEN, THE',
#   'num_of_sat_test_takers': '42',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '370',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '02M374',
#   'school_name': 'GRAMERCY ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '60',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '02M376',
#   'school_name': 'NYC ISCHOOL',
#   'num_of_sat_test_takers': '92',
#   'sat_critical_reading_avg_score': '473',
#   'sat_math_avg_score': '483',
#   'sat_writing_avg_score': '479'},
#  {'dbn': '02M392',
#   'school_name': 'MANHATTAN BUSINESS ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M393',
#   'school_name': 'BUSINESS OF SPORTS SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M394',
#   'school_name': 'EMMA LAZARUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '79',
#   'sat_critical_reading_avg_score': '319',
#   'sat_math_avg_score': '512',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '02M399',
#   'school_name': 'THE HIGH SCHOOL FOR LANGUAGE AND DIPLOMACY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M400',
#   'school_name': 'HIGH SCHOOL FOR ENVIRONMENTAL STUDIES',
#   'num_of_sat_test_takers': '263',
#   'sat_critical_reading_avg_score': '465',
#   'sat_math_avg_score': '493',
#   'sat_writing_avg_score': '461'},
#  {'dbn': '02M407',
#   'school_name': 'INSTITUTE FOR COLLABORATIVE EDUCATION',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '492',
#   'sat_math_avg_score': '465',
#   'sat_writing_avg_score': '467'},
#  {'dbn': '02M408',
#   'school_name': 'PROFESSIONAL PERFORMING ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '94',
#   'sat_critical_reading_avg_score': '509',
#   'sat_math_avg_score': '490',
#   'sat_writing_avg_score': '523'},
#  {'dbn': '02M411',
#   'school_name': 'BARUCH COLLEGE CAMPUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '104',
#   'sat_critical_reading_avg_score': '496',
#   'sat_math_avg_score': '563',
#   'sat_writing_avg_score': '518'},
#  {'dbn': '02M412',
#   'school_name': 'N.Y.C. LAB SCHOOL FOR COLLABORATIVE STUDIES',
#   'num_of_sat_test_takers': '114',
#   'sat_critical_reading_avg_score': '537',
#   'sat_math_avg_score': '590',
#   'sat_writing_avg_score': '550'},
#  {'dbn': '02M413',
#   'school_name': 'SCHOOL OF THE FUTURE HIGH SCHOOL',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '517',
#   'sat_math_avg_score': '533',
#   'sat_writing_avg_score': '515'},
#  {'dbn': '02M414',
#   'school_name': 'N.Y.C. MUSEUM SCHOOL',
#   'num_of_sat_test_takers': '103',
#   'sat_critical_reading_avg_score': '468',
#   'sat_math_avg_score': '492',
#   'sat_writing_avg_score': '459'},
#  {'dbn': '02M416',
#   'school_name': 'ELEANOR ROOSEVELT HIGH SCHOOL',
#   'num_of_sat_test_takers': '127',
#   'sat_critical_reading_avg_score': '572',
#   'sat_math_avg_score': '594',
#   'sat_writing_avg_score': '592'},
#  {'dbn': '02M418',
#   'school_name': 'MILLENNIUM HIGH SCHOOL',
#   'num_of_sat_test_takers': '144',
#   'sat_critical_reading_avg_score': '528',
#   'sat_math_avg_score': '553',
#   'sat_writing_avg_score': '533'},
#  {'dbn': '02M419',
#   'school_name': 'LANDMARK HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '390',
#   'sat_math_avg_score': '399',
#   'sat_writing_avg_score': '381'},
#  {'dbn': '02M420',
#   'school_name': 'HIGH SCHOOL FOR HEALTH PROFESSIONS AND HUMAN SERVICES',
#   'num_of_sat_test_takers': '336',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '449',
#   'sat_writing_avg_score': '428'},
#  {'dbn': '02M425',
#   'school_name': 'LEADERSHIP AND PUBLIC SERVICE HIGH SCHOOL',
#   'num_of_sat_test_takers': '84',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '02M427',
#   'school_name': 'MANHATTAN ACADEMY FOR ARTS & LANGUAGE',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M429',
#   'school_name': 'LEGACY SCHOOL FOR INTEGRATED STUDIES',
#   'num_of_sat_test_takers': '29',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '349'},
#  {'dbn': '02M437',
#   'school_name': 'HUDSON HIGH SCHOOL OF LEARNING TECHNOLOGIES',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M438',
#   'school_name': 'INTERNATIONAL HIGH SCHOOL AT UNION SQUARE',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M439',
#   'school_name': 'MANHATTAN VILLAGE ACADEMY',
#   'num_of_sat_test_takers': '95',
#   'sat_critical_reading_avg_score': '441',
#   'sat_math_avg_score': '473',
#   'sat_writing_avg_score': '458'},
#  {'dbn': '02M440',
#   'school_name': 'BAYARD RUSTIN EDUCATIONAL COMPLEX',
#   'num_of_sat_test_takers': '59',
#   'sat_critical_reading_avg_score': '378',
#   'sat_math_avg_score': '365',
#   'sat_writing_avg_score': '368'},
#  {'dbn': '02M449',
#   'school_name': 'VANGUARD HIGH SCHOOL',
#   'num_of_sat_test_takers': '72',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '416',
#   'sat_writing_avg_score': '388'},
#  {'dbn': '02M459',
#   'school_name': 'MANHATTAN INTERNATIONAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '376',
#   'sat_math_avg_score': '460',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '02M460',
#   'school_name': 'WASHINGTON IRVING HIGH SCHOOL',
#   'num_of_sat_test_takers': '151',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '387',
#   'sat_writing_avg_score': '360'},
#  {'dbn': '02M473',
#   'school_name': 'WASHINGTON IRVING YABC',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '02M475',
#   'school_name': 'STUYVESANT HIGH SCHOOL',
#   'num_of_sat_test_takers': '832',
#   'sat_critical_reading_avg_score': '679',
#   'sat_math_avg_score': '735',
#   'sat_writing_avg_score': '682'},
#  {'dbn': '02M489',
#   'school_name': 'HIGH SCHOOL OF ECONOMICS AND FINANCE',
#   'num_of_sat_test_takers': '167',
#   'sat_critical_reading_avg_score': '443',
#   'sat_math_avg_score': '489',
#   'sat_writing_avg_score': '442'},
#  {'dbn': '02M500',
#   'school_name': 'UNITY CENTER FOR URBAN TECHNOLOGIES',
#   'num_of_sat_test_takers': '25',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '349',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '02M519',
#   'school_name': 'TALENT UNLIMITED HIGH SCHOOL',
#   'num_of_sat_test_takers': '81',
#   'sat_critical_reading_avg_score': '469',
#   'sat_math_avg_score': '472',
#   'sat_writing_avg_score': '475'},
#  {'dbn': '02M520',
#   'school_name': 'MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS',
#   'num_of_sat_test_takers': '264',
#   'sat_critical_reading_avg_score': '407',
#   'sat_math_avg_score': '440',
#   'sat_writing_avg_score': '393'},
#  {'dbn': '02M529',
#   'school_name': 'JACQUELINE KENNEDY ONASSIS HIGH SCHOOL',
#   'num_of_sat_test_takers': '131',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '425',
#   'sat_writing_avg_score': '400'},
#  {'dbn': '02M531',
#   'school_name': 'REPERTORY COMPANY HIGH SCHOOL FOR THEATRE ARTS',
#   'num_of_sat_test_takers': '42',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '404',
#   'sat_writing_avg_score': '420'},
#  {'dbn': '02M542',
#   'school_name': 'MANHATTAN BRIDGES HIGH SCHOOL',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '336',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '344'},
#  {'dbn': '02M543',
#   'school_name': 'NEW DESIGN HIGH SCHOOL',
#   'num_of_sat_test_takers': '73',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '395',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '02M544',
#   'school_name': 'INDEPENDENCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '14',
#   'sat_critical_reading_avg_score': '389',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '335'},
#  {'dbn': '02M545',
#   'school_name': 'HIGH SCHOOL FOR DUAL LANGUAGE AND ASIAN STUDIES',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '412',
#   'sat_math_avg_score': '581',
#   'sat_writing_avg_score': '431'},
#  {'dbn': '02M550',
#   'school_name': 'LIBERTY HIGH SCHOOL ACADEMY FOR NEWCOMERS',
#   'num_of_sat_test_takers': '26',
#   'sat_critical_reading_avg_score': '368',
#   'sat_math_avg_score': '436',
#   'sat_writing_avg_score': '352'},
#  {'dbn': '02M551',
#   'school_name': 'THE URBAN ASSEMBLY NEW YORK HARBOR SCHOOL',
#   'num_of_sat_test_takers': '77',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '423',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '02M560',
#   'school_name': 'HIGH SCHOOL M560 s CITY AS SCHOOL',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '498',
#   'sat_math_avg_score': '440',
#   'sat_writing_avg_score': '477'},
#  {'dbn': '02M565',
#   'school_name': 'URBAN ACADEMY LABORATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '30',
#   'sat_critical_reading_avg_score': '527',
#   'sat_math_avg_score': '508',
#   'sat_writing_avg_score': '512'},
#  {'dbn': '02M570',
#   'school_name': 'SATELLITE ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '33',
#   'sat_critical_reading_avg_score': '350',
#   'sat_math_avg_score': '337',
#   'sat_writing_avg_score': '345'},
#  {'dbn': '02M575',
#   'school_name': 'MANHATTAN COMPREHENSIVE NIGHT AND DAY HIGH SCHOOL',
#   'num_of_sat_test_takers': '121',
#   'sat_critical_reading_avg_score': '345',
#   'sat_math_avg_score': '517',
#   'sat_writing_avg_score': '343'},
#  {'dbn': '02M580',
#   'school_name': 'RICHARD R. GREEN HIGH SCHOOL OF TEACHING',
#   'num_of_sat_test_takers': '84',
#   'sat_critical_reading_avg_score': '408',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '403'},
#  {'dbn': '02M586',
#   'school_name': 'HARVEY MILK HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '458',
#   'sat_math_avg_score': '416',
#   'sat_writing_avg_score': '429'},
#  {'dbn': '02M600',
#   'school_name': 'THE HIGH SCHOOL OF FASHION INDUSTRIES',
#   'num_of_sat_test_takers': '335',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '423',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '02M605',
#   'school_name': 'HUMANITIES PREPARATORY ACADEMY',
#   'num_of_sat_test_takers': '36',
#   'sat_critical_reading_avg_score': '426',
#   'sat_math_avg_score': '403',
#   'sat_writing_avg_score': '426'},
#  {'dbn': '02M615',
#   'school_name': 'CHELSEA CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '83',
#   'sat_critical_reading_avg_score': '399',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '390'},
#  {'dbn': '02M620',
#   'school_name': 'NORMAN THOMAS HIGH SCHOOL',
#   'num_of_sat_test_takers': '154',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '02M625',
#   'school_name': 'HIGH SCHOOL OF GRAPHIC COMMUNICATION ARTS',
#   'num_of_sat_test_takers': '191',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '382',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '02M630',
#   'school_name': 'ART AND DESIGN HIGH SCHOOL',
#   'num_of_sat_test_takers': '270',
#   'sat_critical_reading_avg_score': '444',
#   'sat_math_avg_score': '441',
#   'sat_writing_avg_score': '430'},
#  {'dbn': '02M655',
#   'school_name': 'LIFE SCIENCES SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '409',
#   'sat_math_avg_score': '424',
#   'sat_writing_avg_score': '403'},
#  {'dbn': '03M283',
#   'school_name': 'MANHATTAN THEATRE LAB HIGH SCHOOL',
#   'num_of_sat_test_takers': '27',
#   'sat_critical_reading_avg_score': '406',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '408'},
#  {'dbn': '03M299',
#   'school_name': 'HIGH SCHOOL FOR ARTS, IMAGINATION AND INQUIRY',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '374',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '374'},
#  {'dbn': '03M307',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR MEDIA STUDIES, THE',
#   'num_of_sat_test_takers': '41',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '03M402',
#   'school_name': 'THE URBAN ASSEMBLY SCHOOL FOR GREEN CAREERS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M403',
#   'school_name': 'THE GLOBAL LEARNING COLLABORATIVE',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M404',
#   'school_name': 'INNOVATION DIPLOMA PLUS',
#   'num_of_sat_test_takers': '12',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '403',
#   'sat_writing_avg_score': '381'},
#  {'dbn': '03M415',
#   'school_name': 'WADLEIGH SECONDARY SCHOOL FOR THE PERFORMING & VISUAL ARTS',
#   'num_of_sat_test_takers': '32',
#   'sat_critical_reading_avg_score': '371',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '03M417',
#   'school_name': 'FRANK MCCOURT HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M470',
#   'school_name': 'LOUIS D. BRANDEIS HIGH SCHOOL',
#   'num_of_sat_test_takers': '131',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '358'},
#  {'dbn': '03M479',
#   'school_name': 'BEACON HIGH SCHOOL',
#   'num_of_sat_test_takers': '261',
#   'sat_critical_reading_avg_score': '577',
#   'sat_math_avg_score': '575',
#   'sat_writing_avg_score': '592'},
#  {'dbn': '03M485',
#   'school_name': 'FIORELLO H. LAGUARDIA HIGH SCHOOL OF MUSIC & ART AND PERFORMING ARTS',
#   'num_of_sat_test_takers': '531',
#   'sat_critical_reading_avg_score': '566',
#   'sat_math_avg_score': '564',
#   'sat_writing_avg_score': '577'},
#  {'dbn': '03M492',
#   'school_name': 'HIGH SCHOOL FOR LAW, ADVOCACY AND COMMUNITY JUSTICE',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '396',
#   'sat_math_avg_score': '398',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '03M494',
#   'school_name': 'HIGH SCHOOL OF ARTS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '75',
#   'sat_critical_reading_avg_score': '433',
#   'sat_math_avg_score': '433',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '03M505',
#   'school_name': 'EDWARD A. REYNOLDS WEST SIDE HIGH SCHOOL',
#   'num_of_sat_test_takers': '35',
#   'sat_critical_reading_avg_score': '401',
#   'sat_math_avg_score': '369',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '03M541',
#   'school_name': 'MANHATTAN / HUNTER SCIENCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '111',
#   'sat_critical_reading_avg_score': '473',
#   'sat_math_avg_score': '506',
#   'sat_writing_avg_score': '467'},
#  {'dbn': '03M577',
#   'school_name': 'YOUNG ADULT BOROUGH CENTER AT LOUIS D. BRANDEIS HS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '03M860',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY II SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '43',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '04M409',
#   'school_name': 'COALITION SCHOOL FOR SOCIAL CHANGE',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '354',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '373'},
#  {'dbn': '04M435',
#   'school_name': 'MANHATTAN CENTER FOR SCIENCE AND MATHEMATICS',
#   'num_of_sat_test_takers': '375',
#   'sat_critical_reading_avg_score': '461',
#   'sat_math_avg_score': '514',
#   'sat_writing_avg_score': '455'},
#  {'dbn': '04M495',
#   'school_name': 'PARK EAST HIGH SCHOOL',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '04M555',
#   'school_name': 'CENTRAL PARK EAST HIGH SCHOOL',
#   'num_of_sat_test_takers': '73',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '421',
#   'sat_writing_avg_score': '395'},
#  {'dbn': '04M610',
#   'school_name': "YOUNG WOMEN'S LEADERSHIP SCHOOL",
#   'num_of_sat_test_takers': '70',
#   'sat_critical_reading_avg_score': '432',
#   'sat_math_avg_score': '446',
#   'sat_writing_avg_score': '448'},
#  {'dbn': '04M635',
#   'school_name': 'ACADEMY OF ENVIRONMENTAL SCIENCE SECONDARY HIGH SCHOOL',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '369',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '04M680',
#   'school_name': 'HERITAGE SCHOOL, THE',
#   'num_of_sat_test_takers': '31',
#   'sat_critical_reading_avg_score': '358',
#   'sat_math_avg_score': '351',
#   'sat_writing_avg_score': '345'},
#  {'dbn': '05M285',
#   'school_name': 'HARLEM RENAISSANCE HIGH SCHOOL',
#   'num_of_sat_test_takers': '29',
#   'sat_critical_reading_avg_score': '357',
#   'sat_math_avg_score': '318',
#   'sat_writing_avg_score': '333'},
#  {'dbn': '05M304',
#   'school_name': 'MOTT HALL HIGH SCHOOL',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '413',
#   'sat_math_avg_score': '399',
#   'sat_writing_avg_score': '398'},
#  {'dbn': '05M362',
#   'school_name': 'COLUMBIA SECONDARY SCHOOL FOR MATH, SCIENCE, AND ENGINEERING',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '05M367',
#   'school_name': 'ACADEMY FOR SOCIAL ACTION: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '33',
#   'sat_critical_reading_avg_score': '354',
#   'sat_math_avg_score': '366',
#   'sat_writing_avg_score': '342'},
#  {'dbn': '05M369',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR THE PERFORMING ARTS',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '360',
#   'sat_math_avg_score': '353',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '05M469',
#   'school_name': 'CHOIR ACADEMY OF HARLEM',
#   'num_of_sat_test_takers': '20',
#   'sat_critical_reading_avg_score': '354',
#   'sat_math_avg_score': '360',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '05M499',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY',
#   'num_of_sat_test_takers': '214',
#   'sat_critical_reading_avg_score': '458',
#   'sat_math_avg_score': '474',
#   'sat_writing_avg_score': '442'},
#  {'dbn': '05M670',
#   'school_name': 'THURGOOD MARSHALL ACADEMY FOR LEARNING AND SOCIAL CHANGE',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '396',
#   'sat_math_avg_score': '402',
#   'sat_writing_avg_score': '404'},
#  {'dbn': '05M685',
#   'school_name': 'BREAD & ROSES INTEGRATED ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '361',
#   'sat_writing_avg_score': '355'},
#  {'dbn': '05M692',
#   'school_name': 'HIGH SCHOOL FOR MATHEMATICS, SCIENCE AND ENGINEERING AT CITY COLLEGE',
#   'num_of_sat_test_takers': '101',
#   'sat_critical_reading_avg_score': '605',
#   'sat_math_avg_score': '654',
#   'sat_writing_avg_score': '588'},
#  {'dbn': '06M293',
#   'school_name': 'CITY COLLEGE ACADEMY OF THE ARTS',
#   'num_of_sat_test_takers': '60',
#   'sat_critical_reading_avg_score': '408',
#   'sat_math_avg_score': '446',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '06M346',
#   'school_name': 'COMMUNITY HEALTH ACADEMY OF THE HEIGHTS',
#   'num_of_sat_test_takers': '55',
#   'sat_critical_reading_avg_score': '362',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '06M348',
#   'school_name': 'WASHINGTON HEIGHTS EXPEDITIONARY LEARNING SCHOOL',
#   'num_of_sat_test_takers': '70',
#   'sat_critical_reading_avg_score': '380',
#   'sat_math_avg_score': '395',
#   'sat_writing_avg_score': '399'},
#  {'dbn': '06M423',
#   'school_name': 'HIGH SCHOOL FOR EXCELLENCE AND INNOVATION',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '06M457',
#   'school_name': 'GEORGE WASHINGTON YABC',
#   'num_of_sat_test_takers': '7',
#   'sat_critical_reading_avg_score': '394',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '346'},
#  {'dbn': '06M462',
#   'school_name': 'HIGH SCHOOL FOR INTERNATIONAL BUSINESS AND FINANCE',
#   'num_of_sat_test_takers': '76',
#   'sat_critical_reading_avg_score': '365',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '378'},
#  {'dbn': '06M463',
#   'school_name': 'HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS',
#   'num_of_sat_test_takers': '63',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '380',
#   'sat_writing_avg_score': '349'},
#  {'dbn': '06M467',
#   'school_name': 'HIGH SCHOOL FOR LAW AND PUBLIC SERVICE',
#   'num_of_sat_test_takers': '94',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '06M468',
#   'school_name': 'HIGH SCHOOL FOR HEALTH CAREERS AND SCIENCES',
#   'num_of_sat_test_takers': '24',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '422',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '06M540',
#   'school_name': 'A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '228',
#   'sat_critical_reading_avg_score': '430',
#   'sat_math_avg_score': '456',
#   'sat_writing_avg_score': '423'},
#  {'dbn': '06M552',
#   'school_name': 'GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND MATHEMATICS',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '339',
#   'sat_math_avg_score': '349',
#   'sat_writing_avg_score': '326'},
#  {'dbn': '07X221',
#   'school_name': 'SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '65',
#   'sat_critical_reading_avg_score': '364',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '348'},
#  {'dbn': '07X321',
#   'school_name': 'CROTONA ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '379',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '07X334',
#   'school_name': 'INTERNATIONAL COMMUNITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '34',
#   'sat_critical_reading_avg_score': '310',
#   'sat_math_avg_score': '324',
#   'sat_writing_avg_score': '311'},
#  {'dbn': '07X379',
#   'school_name': 'JILL CHAIFETZ TRANSFER HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '07X381',
#   'school_name': 'BRONX HAVEN HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '07X427',
#   'school_name': 'COMMUNITY SCHOOL FOR SOCIAL JUSTICE',
#   'num_of_sat_test_takers': '43',
#   'sat_critical_reading_avg_score': '361',
#   'sat_math_avg_score': '359',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '07X473',
#   'school_name': 'MOTT HAVEN VILLAGE PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '63',
#   'sat_critical_reading_avg_score': '351',
#   'sat_math_avg_score': '375',
#   'sat_writing_avg_score': '371'},
#  {'dbn': '07X495',
#   'school_name': 'UNIVERSITY HEIGHTS SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '79',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '404'},
#  {'dbn': '07X500',
#   'school_name': 'HOSTOSsLINCOLN ACADEMY OF SCIENCE',
#   'num_of_sat_test_takers': '66',
#   'sat_critical_reading_avg_score': '420',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '411'},
#  {'dbn': '07X520',
#   'school_name': 'FOREIGN LANGUAGE ACADEMY OF GLOBAL STUDIES',
#   'num_of_sat_test_takers': '64',
#   'sat_critical_reading_avg_score': '399',
#   'sat_math_avg_score': '396',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '07X527',
#   'school_name': 'BRONX LEADERSHIP ACADEMY II HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '362',
#   'sat_math_avg_score': '378',
#   'sat_writing_avg_score': '363'},
#  {'dbn': '07X547',
#   'school_name': 'NEW EXPLORERS HIGH SCHOOL',
#   'num_of_sat_test_takers': '28',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '07X548',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR CAREERS IN SPORTS',
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '411',
#   'sat_writing_avg_score': '383'},
#  {'dbn': '07X551',
#   'school_name': 'BRONX ACADEMY OF LETTERS',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '413',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '407'},
#  {'dbn': '07X600',
#   'school_name': 'ALFRED E. SMITH CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '76',
#   'sat_critical_reading_avg_score': '394',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '07X655',
#   'school_name': 'SAMUEL GOMPERS CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '47',
#   'sat_critical_reading_avg_score': '398',
#   'sat_math_avg_score': '416',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '07X670',
#   'school_name': 'HEALTH OPPORTUNITIES HIGH SCHOOL',
#   'num_of_sat_test_takers': '114',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '08X269',
#   'school_name': 'BRONX STUDIO SCHOOL FOR WRITERS AND ARTISTS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X282',
#   'school_name': "WOMEN'S ACADEMY OF EXCELLENCE",
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '407',
#   'sat_math_avg_score': '386',
#   'sat_writing_avg_score': '378'},
#  {'dbn': '08X293',
#   'school_name': 'RENAISSANCE HIGH SCHOOL FOR MUSICAL THEATER & TECHNOLOGY',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '385',
#   'sat_writing_avg_score': '389'},
#  {'dbn': '08X295',
#   'school_name': 'GATEWAY SCHOOL FOR ENVIRONMENTAL RESEARCH AND TECHNOLOGY',
#   'num_of_sat_test_takers': '41',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '390',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '08X305',
#   'school_name': 'PABLO NERUDA ACADEMY FOR ARCHITECTURE AND WORLD STUDIES',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '337',
#   'sat_math_avg_score': '361',
#   'sat_writing_avg_score': '340'},
#  {'dbn': '08X312',
#   'school_name': 'MILLENNIUM ART ACADEMY',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '402',
#   'sat_writing_avg_score': '375'},
#  {'dbn': '08X332',
#   'school_name': 'HOLCOMBE L. RUCKER SCHOOL OF COMMUNITY RESEARCH',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '350'},
#  {'dbn': '08X367',
#   'school_name': 'ARCHIMEDES ACADEMY FOR MATH, SCIENCE AND TECHNOLOGY APPLICATIONS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X376',
#   'school_name': 'ANTONIA PANTOJA PREPARATORY ACADEMY, A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X377',
#   'school_name': 'BRONX COMMUNITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '369',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '08X405',
#   'school_name': 'HERBERT H. LEHMAN HIGH SCHOOL',
#   'num_of_sat_test_takers': '415',
#   'sat_critical_reading_avg_score': '412',
#   'sat_math_avg_score': '436',
#   'sat_writing_avg_score': '393'},
#  {'dbn': '08X408',
#   'school_name': 'HERBERT H. LEHMAN YABC',
#   'num_of_sat_test_takers': '6',
#   'sat_critical_reading_avg_score': '402',
#   'sat_math_avg_score': '373',
#   'sat_writing_avg_score': '413'},
#  {'dbn': '08X432',
#   'school_name': 'BRONX BRIDGES HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X452',
#   'school_name': 'BRONX GUILD',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '365'},
#  {'dbn': '08X507',
#   'school_name': 'STEVENSON YABC',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X519',
#   'school_name': 'FELISA RINCON DE GAUTIER INSTITUTE FOR LAW AND PUBLIC POLICY, THE',
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '370',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '08X530',
#   'school_name': 'BANANA KELLY HIGH SCHOOL',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '377'},
#  {'dbn': '08X537',
#   'school_name': 'BRONX ARENA HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '08X540',
#   'school_name': 'SCHOOL FOR COMMUNITY RESEARCH AND LEARNING',
#   'num_of_sat_test_takers': '16',
#   'sat_critical_reading_avg_score': '366',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '368'},
#  {'dbn': '08X560',
#   'school_name': 'HIGH SCHOOL X560 s BRONX ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '399'},
#  {'dbn': '08X650',
#   'school_name': 'JANE ADDAMS HIGH SCHOOL FOR ACADEMIC CAREERS',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '359',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '09X227',
#   'school_name': 'BRONX EXPEDITIONARY LEARNING HIGH SCHOOL',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '324',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '349'},
#  {'dbn': '09X231',
#   'school_name': 'EAGLE ACADEMY FOR YOUNG MEN',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '387',
#   'sat_writing_avg_score': '374'},
#  {'dbn': '09X239',
#   'school_name': 'URBAN ASSEMBLY ACADEMY FOR HISTORY AND CITIZENSHIP FOR YOUNG MEN, THE',
#   'num_of_sat_test_takers': '33',
#   'sat_critical_reading_avg_score': '372',
#   'sat_math_avg_score': '355',
#   'sat_writing_avg_score': '357'},
#  {'dbn': '09X241',
#   'school_name': 'URBAN ASSEMBLY SCHOOL FOR APPLIED MATH AND SCIENCE, THE',
#   'num_of_sat_test_takers': '80',
#   'sat_critical_reading_avg_score': '411',
#   'sat_math_avg_score': '464',
#   'sat_writing_avg_score': '415'},
#  {'dbn': '09X250',
#   'school_name': 'EXIMIUS COLLEGE PREPARATORY ACADEMY: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '393',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '09X252',
#   'school_name': 'MOTT HALL BRONX HIGH SCHOOL',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '369',
#   'sat_math_avg_score': '367',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '09X260',
#   'school_name': 'BRONX CENTER FOR SCIENCE AND MATHEMATICS',
#   'num_of_sat_test_takers': '81',
#   'sat_critical_reading_avg_score': '459',
#   'sat_math_avg_score': '480',
#   'sat_writing_avg_score': '457'},
#  {'dbn': '09X263',
#   'school_name': 'VALIDUS PREPARATORY ACADEMY: AN EXPEDITIONARY LEARNING SCHOOL',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '363',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '09X276',
#   'school_name': 'LEADERSHIP INSTITUTE',
#   'num_of_sat_test_takers': '30',
#   'sat_critical_reading_avg_score': '361',
#   'sat_math_avg_score': '353',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '09X297',
#   'school_name': 'MORRIS ACADEMY FOR COLLABORATIVE STUDIES',
#   'num_of_sat_test_takers': '38',
#   'sat_critical_reading_avg_score': '386',
#   'sat_math_avg_score': '386',
#   'sat_writing_avg_score': '376'},
#  {'dbn': '09X324',
#   'school_name': 'BRONX EARLY COLLEGE ACADEMY FOR TEACHING & LEARNING',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '09X329',
#   'school_name': 'DREAMYARD PREPARATORY SCHOOL',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '365',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '09X365',
#   'school_name': 'ACADEMY FOR LANGUAGE AND TECHNOLOGY',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '315',
#   'sat_math_avg_score': '339',
#   'sat_writing_avg_score': '297'},
#  {'dbn': '09X403',
#   'school_name': 'BRONX INTERNATIONAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '314',
#   'sat_math_avg_score': '312',
#   'sat_writing_avg_score': '339'},
#  {'dbn': '09X404',
#   'school_name': 'SCHOOL FOR EXCELLENCE',
#   'num_of_sat_test_takers': '32',
#   'sat_critical_reading_avg_score': '363',
#   'sat_math_avg_score': '360',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '09X412',
#   'school_name': 'BRONX HIGH SCHOOL OF BUSINESS',
#   'num_of_sat_test_takers': '34',
#   'sat_critical_reading_avg_score': '356',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '351'},
#  {'dbn': '09X413',
#   'school_name': 'BRONX HIGH SCHOOL FOR MEDICAL SCIENCE',
#   'num_of_sat_test_takers': '64',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '419',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '09X414',
#   'school_name': 'JONATHAN LEVIN HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS',
#   'num_of_sat_test_takers': '35',
#   'sat_critical_reading_avg_score': '379',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '379'},
#  {'dbn': '09X505',
#   'school_name': 'BRONX SCHOOL FOR LAW, GOVERNMENT AND JUSTICE',
#   'num_of_sat_test_takers': '80',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '09X517',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY III SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '368',
#   'sat_math_avg_score': '384',
#   'sat_writing_avg_score': '369'},
#  {'dbn': '09X525',
#   'school_name': 'BRONX LEADERSHIP ACADEMY HIGH SCHOOL',
#   'num_of_sat_test_takers': '114',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '388'},
#  {'dbn': '09X543',
#   'school_name': 'HIGH SCHOOL FOR VIOLIN AND DANCE',
#   'num_of_sat_test_takers': '27',
#   'sat_critical_reading_avg_score': '353',
#   'sat_math_avg_score': '315',
#   'sat_writing_avg_score': '371'},
#  {'dbn': '10X141',
#   'school_name': 'RIVERDALE / KINGSBRIDGE ACADEMY (MIDDLE SCHOOL / HIGH SCHOOL 141)',
#   'num_of_sat_test_takers': '113',
#   'sat_critical_reading_avg_score': '438',
#   'sat_math_avg_score': '455',
#   'sat_writing_avg_score': '440'},
#  {'dbn': '10X213',
#   'school_name': 'BRONX ENGINEERING AND TECHNOLOGY ACADEMY',
#   'num_of_sat_test_takers': '86',
#   'sat_critical_reading_avg_score': '373',
#   'sat_math_avg_score': '412',
#   'sat_writing_avg_score': '365'},
#  {'dbn': '10X225',
#   'school_name': 'THEATRE ARTS PRODUCTION COMPANY SCHOOL',
#   'num_of_sat_test_takers': '59',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '10X237',
#   'school_name': 'THE MARIE CURIE SCHOOL FOR MEDICINE, NURSING, AND HEALTH PROFESSIONS',
#   'num_of_sat_test_takers': '79',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '393',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '10X243',
#   'school_name': 'WEST BRONX ACADEMY FOR THE FUTURE',
#   'num_of_sat_test_takers': '26',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '406',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '10X268',
#   'school_name': 'KINGSBRIDGE INTERNATIONAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '304',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '302'},
#  {'dbn': '10X284',
#   'school_name': 'BRONX SCHOOL OF LAW AND FINANCE',
#   'num_of_sat_test_takers': '54',
#   'sat_critical_reading_avg_score': '402',
#   'sat_math_avg_score': '395',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '10X319',
#   'school_name': 'PROVIDING URBAN LEARNERS SUCCESS IN EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '10X342',
#   'school_name': 'INTERNATIONAL SCHOOL FOR LIBERAL ARTS',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '300',
#   'sat_math_avg_score': '333',
#   'sat_writing_avg_score': '301'},
#  {'dbn': '10X368',
#   'school_name': 'INsTECH ACADEMY (M.S. / HIGH SCHOOL 368)',
#   'num_of_sat_test_takers': '111',
#   'sat_critical_reading_avg_score': '390',
#   'sat_math_avg_score': '408',
#   'sat_writing_avg_score': '383'},
#  {'dbn': '10X374',
#   'school_name': 'KNOWLEDGE AND POWER PREPARATORY ACADEMY INTERNATIONAL HIGH SCHOOL (KAPPA)',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '392',
#   'sat_math_avg_score': '401',
#   'sat_writing_avg_score': '387'},
#  {'dbn': '10X397',
#   'school_name': 'ENGLISH LANGUAGE LEARNERS AND INTERNATIONAL SUPPORT PREPARATORY ACADEMY (ELLIS)',
#   'num_of_sat_test_takers': '38',
#   'sat_critical_reading_avg_score': '343',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '330'},
#  {'dbn': '10X433',
#   'school_name': 'HIGH SCHOOL FOR TEACHING AND THE PROFESSIONS',
#   'num_of_sat_test_takers': '57',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '365'},
#  {'dbn': '10X434',
#   'school_name': 'BELMONT PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '51',
#   'sat_critical_reading_avg_score': '404',
#   'sat_math_avg_score': '418',
#   'sat_writing_avg_score': '400'},
#  {'dbn': '10X437',
#   'school_name': 'FORDHAM HIGH SCHOOL FOR THE ARTS',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '355',
#   'sat_math_avg_score': '350',
#   'sat_writing_avg_score': '372'},
#  {'dbn': '10X438',
#   'school_name': 'FORDHAM LEADERSHIP ACADEMY FOR BUSINESS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '63',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '385',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '10X439',
#   'school_name': 'BRONX HIGH SCHOOL FOR LAW AND COMMUNITY SERVICE',
#   'num_of_sat_test_takers': '65',
#   'sat_critical_reading_avg_score': '366',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '352'},
#  {'dbn': '10X440',
#   'school_name': 'DEWITT CLINTON HIGH SCHOOL',
#   'num_of_sat_test_takers': '443',
#   'sat_critical_reading_avg_score': '419',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '410'},
#  {'dbn': '10X442',
#   'school_name': 'CELIA CRUZ BRONX HIGH SCHOOL OF MUSIC, THE',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '420',
#   'sat_writing_avg_score': '427'},
#  {'dbn': '10X445',
#   'school_name': 'BRONX HIGH SCHOOL OF SCIENCE',
#   'num_of_sat_test_takers': '731',
#   'sat_critical_reading_avg_score': '632',
#   'sat_math_avg_score': '688',
#   'sat_writing_avg_score': '649'},
#  {'dbn': '10X475',
#   'school_name': 'JOHN F. KENNEDY HIGH SCHOOL',
#   'num_of_sat_test_takers': '109',
#   'sat_critical_reading_avg_score': '351',
#   'sat_math_avg_score': '362',
#   'sat_writing_avg_score': '339'},
#  {'dbn': '10X477',
#   'school_name': 'MARBLE HILL HIGH SCHOOL FOR INTERNATIONAL STUDIES',
#   'num_of_sat_test_takers': '99',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '435',
#   'sat_writing_avg_score': '414'},
#  {'dbn': '10X478',
#   'school_name': 'LEARNING TO WORK GED AT JOHN F. KENNEDY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '10X546',
#   'school_name': 'BRONX THEATRE HIGH SCHOOL',
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '348',
#   'sat_math_avg_score': '362',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '10X549',
#   'school_name': 'DISCOVERY HIGH SCHOOL',
#   'num_of_sat_test_takers': '55',
#   'sat_critical_reading_avg_score': '372',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '10X660',
#   'school_name': 'GRACE DODGE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '73',
#   'sat_critical_reading_avg_score': '362',
#   'sat_math_avg_score': '382',
#   'sat_writing_avg_score': '356'},
#  {'dbn': '10X667',
#   'school_name': 'GRACE DODGE YABC',
#   'num_of_sat_test_takers': '10',
#   'sat_critical_reading_avg_score': '350',
#   'sat_math_avg_score': '356',
#   'sat_writing_avg_score': '317'},
#  {'dbn': '10X696',
#   'school_name': 'HIGH SCHOOL OF AMERICAN STUDIES AT LEHMAN COLLEGE',
#   'num_of_sat_test_takers': '92',
#   'sat_critical_reading_avg_score': '636',
#   'sat_math_avg_score': '648',
#   'sat_writing_avg_score': '636'},
#  {'dbn': '11X249',
#   'school_name': 'BRONX HEALTH SCIENCES HIGH SCHOOL',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '382'},
#  {'dbn': '11X253',
#   'school_name': 'BRONX HIGH SCHOOL FOR WRITING AND COMMUNICATION ARTS',
#   'num_of_sat_test_takers': '46',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '357',
#   'sat_writing_avg_score': '390'},
#  {'dbn': '11X265',
#   'school_name': 'BRONX LAB SCHOOL',
#   'num_of_sat_test_takers': '81',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '11X270',
#   'school_name': 'ACADEMY FOR SCHOLARSHIP AND ENTREPRENEURSHIP: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '56',
#   'sat_critical_reading_avg_score': '386',
#   'sat_math_avg_score': '394',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '11X275',
#   'school_name': 'HIGH SCHOOL OF COMPUTERS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '72',
#   'sat_critical_reading_avg_score': '381',
#   'sat_math_avg_score': '376',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '11X288',
#   'school_name': 'COLLEGIATE INSTITUTE FOR MATH AND SCIENCE',
#   'num_of_sat_test_takers': '97',
#   'sat_critical_reading_avg_score': '444',
#   'sat_math_avg_score': '471',
#   'sat_writing_avg_score': '433'},
#  {'dbn': '11X290',
#   'school_name': 'BRONX ACADEMY OF HEALTH CAREERS',
#   'num_of_sat_test_takers': '69',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '365',
#   'sat_writing_avg_score': '383'},
#  {'dbn': '11X299',
#   'school_name': 'ASTOR COLLEGIATE ACADEMY',
#   'num_of_sat_test_takers': '60',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '391',
#   'sat_writing_avg_score': '391'},
#  {'dbn': '11X415',
#   'school_name': 'CHRISTOPHER COLUMBUS HIGH SCHOOL',
#   'num_of_sat_test_takers': '121',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '361',
#   'sat_writing_avg_score': '353'},
#  {'dbn': '11X417',
#   'school_name': 'YOUNG ADULT BOROUGH CNTR CHRISTOPHER COLUMBUS HS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '11X418',
#   'school_name': 'BRONX HIGH SCHOOL FOR THE VISUAL ARTS',
#   'num_of_sat_test_takers': '48',
#   'sat_critical_reading_avg_score': '419',
#   'sat_math_avg_score': '433',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '11X455',
# ...
#   'sat_math_avg_score': '434',
#   'sat_writing_avg_score': '420'},
#  {'dbn': '27Q260',
#   'school_name': 'FREDERICK DOUGLASS ACADEMY VI HIGH SCHOOL',
#   'num_of_sat_test_takers': '87',
#   'sat_critical_reading_avg_score': '387',
#   'sat_math_avg_score': '385',
#   'sat_writing_avg_score': '373'},
#  {'dbn': '27Q262',
#   'school_name': 'CHANNEL VIEW SCHOOL FOR RESEARCH',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '432',
#   'sat_math_avg_score': '419',
#   'sat_writing_avg_score': '401'},
#  {'dbn': '27Q302',
#   'school_name': 'QUEENS HIGH SCHOOL FOR INFORMATION, RESEARCH, AND TECHNOLOGY',
#   'num_of_sat_test_takers': '44',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '401',
#   'sat_writing_avg_score': '364'},
#  {'dbn': '27Q308',
#   'school_name': 'ROBERT H. GODDARD HIGH SCHOOL OF COMMUNICATION ARTS AND TECHNOLOGY',
#   'num_of_sat_test_takers': '93',
#   'sat_critical_reading_avg_score': '423',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '27Q309',
#   'school_name': 'ACADEMY OF MEDICAL TECHNOLOGY: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '36',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '379',
#   'sat_writing_avg_score': '348'},
#  {'dbn': '27Q323',
#   'school_name': "SCHOLARS' ACADEMY",
#   'num_of_sat_test_takers': '89',
#   'sat_critical_reading_avg_score': '499',
#   'sat_math_avg_score': '537',
#   'sat_writing_avg_score': '496'},
#  {'dbn': '27Q400',
#   'school_name': 'AUGUST MARTIN HIGH SCHOOL',
#   'num_of_sat_test_takers': '101',
#   'sat_critical_reading_avg_score': '377',
#   'sat_math_avg_score': '371',
#   'sat_writing_avg_score': '360'},
#  {'dbn': '27Q410',
#   'school_name': 'BEACH CHANNEL HIGH SCHOOL',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '396',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '27Q475',
#   'school_name': 'RICHMOND HILL HIGH SCHOOL',
#   'num_of_sat_test_takers': '404',
#   'sat_critical_reading_avg_score': '382',
#   'sat_math_avg_score': '404',
#   'sat_writing_avg_score': '368'},
#  {'dbn': '27Q480',
#   'school_name': 'JOHN ADAMS HIGH SCHOOL',
#   'num_of_sat_test_takers': '403',
#   'sat_critical_reading_avg_score': '391',
#   'sat_math_avg_score': '409',
#   'sat_writing_avg_score': '392'},
#  {'dbn': '27Q650',
#   'school_name': 'HIGH SCHOOL FOR CONSTRUCTION TRADES, ENGINEERING AND ARCHITECTURE',
#   'num_of_sat_test_takers': '194',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '491',
#   'sat_writing_avg_score': '425'},
#  {'dbn': '28Q284',
#   'school_name': 'YORK EARLY COLLEGE ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '28Q310',
#   'school_name': 'QUEENS COLLEGIATE: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '420',
#   'sat_math_avg_score': '445',
#   'sat_writing_avg_score': '400'},
#  {'dbn': '28Q325',
#   'school_name': 'HILLSIDE ARTS & LETTERS ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '28Q338',
#   'school_name': 'QUEENS SATELLITE HIGH SCHOOL FOR OPPORTUNITY',
#   'num_of_sat_test_takers': '6',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '408',
#   'sat_writing_avg_score': '367'},
#  {'dbn': '28Q350',
#   'school_name': 'JAMAICA GATEWAY TO THE SCIENCES',
#   'num_of_sat_test_takers': '25',
#   'sat_critical_reading_avg_score': '430',
#   'sat_math_avg_score': '452',
#   'sat_writing_avg_score': '425'},
#  {'dbn': '28Q440',
#   'school_name': 'FOREST HILLS HIGH SCHOOL',
#   'num_of_sat_test_takers': '762',
#   'sat_critical_reading_avg_score': '456',
#   'sat_math_avg_score': '497',
#   'sat_writing_avg_score': '454'},
#  {'dbn': '28Q470',
#   'school_name': 'JAMAICA HIGH SCHOOL',
#   'num_of_sat_test_takers': '90',
#   'sat_critical_reading_avg_score': '342',
#   'sat_math_avg_score': '368',
#   'sat_writing_avg_score': '353'},
#  {'dbn': '28Q505',
#   'school_name': 'HILLCREST HIGH SCHOOL',
#   'num_of_sat_test_takers': '462',
#   'sat_critical_reading_avg_score': '395',
#   'sat_math_avg_score': '413',
#   'sat_writing_avg_score': '386'},
#  {'dbn': '28Q620',
#   'school_name': 'THOMAS A. EDISON CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '422',
#   'sat_critical_reading_avg_score': '452',
#   'sat_math_avg_score': '478',
#   'sat_writing_avg_score': '442'},
#  {'dbn': '28Q680',
#   'school_name': 'QUEENS GATEWAY TO HEALTH SCIENCES SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '99',
#   'sat_critical_reading_avg_score': '513',
#   'sat_math_avg_score': '523',
#   'sat_writing_avg_score': '502'},
#  {'dbn': '28Q686',
#   'school_name': 'QUEENS METROPOLITAN HIGH SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '28Q687',
#   'school_name': 'QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK COLLEGE',
#   'num_of_sat_test_takers': '121',
#   'sat_critical_reading_avg_score': '612',
#   'sat_math_avg_score': '660',
#   'sat_writing_avg_score': '596'},
#  {'dbn': '28Q690',
#   'school_name': 'HIGH SCHOOL FOR LAW ENFORCEMENT AND PUBLIC SAFETY',
#   'num_of_sat_test_takers': '74',
#   'sat_critical_reading_avg_score': '406',
#   'sat_math_avg_score': '406',
#   'sat_writing_avg_score': '384'},
#  {'dbn': '28Q896',
#   'school_name': "YOUNG WOMEN'S LEADERSHIP SCHOOL, QUEENS",
#   'num_of_sat_test_takers': '68',
#   'sat_critical_reading_avg_score': '439',
#   'sat_math_avg_score': '445',
#   'sat_writing_avg_score': '432'},
#  {'dbn': '29Q248',
#   'school_name': 'QUEENS PREPARATORY ACADEMY',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '360',
#   'sat_math_avg_score': '380',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '29Q259',
#   'school_name': 'PATHWAYS COLLEGE PREPARATORY SCHOOL: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '46',
#   'sat_critical_reading_avg_score': '401',
#   'sat_math_avg_score': '397',
#   'sat_writing_avg_score': '375'},
#  {'dbn': '29Q265',
#   'school_name': 'EXCELSIOR PREPARATORY HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '402',
#   'sat_math_avg_score': '398',
#   'sat_writing_avg_score': '402'},
#  {'dbn': '29Q272',
#   'school_name': 'GEORGE WASHINGTON CARVER HIGH SCHOOL FOR THE SCIENCES',
#   'num_of_sat_test_takers': '59',
#   'sat_critical_reading_avg_score': '436',
#   'sat_math_avg_score': '427',
#   'sat_writing_avg_score': '424'},
#  {'dbn': '29Q283',
#   'school_name': 'PREPARATORY ACADEMY FOR WRITERS: A COLLEGE BOARD SCHOOL',
#   'num_of_sat_test_takers': '43',
#   'sat_critical_reading_avg_score': '370',
#   'sat_math_avg_score': '367',
#   'sat_writing_avg_score': '363'},
#  {'dbn': '29Q326',
#   'school_name': 'CAMBRIA HEIGHTS ACADEMY',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '29Q492',
#   'school_name': 'MATHEMATICS, SCIENCE RESEARCH AND TECHNOLOGY MAGNET HIGH SCHOOL',
#   'num_of_sat_test_takers': '78',
#   'sat_critical_reading_avg_score': '400',
#   'sat_math_avg_score': '426',
#   'sat_writing_avg_score': '394'},
#  {'dbn': '29Q494',
#   'school_name': 'LAW, GOVERNMENT AND COMMUNITY SERVICE HIGH SCHOOL',
#   'num_of_sat_test_takers': '52',
#   'sat_critical_reading_avg_score': '385',
#   'sat_math_avg_score': '377',
#   'sat_writing_avg_score': '377'},
#  {'dbn': '29Q496',
#   'school_name': 'BUSINESS, COMPUTER APPLICATIONS & ENTREPRENEURSHIP HIGH SCHOOL',
#   'num_of_sat_test_takers': '49',
#   'sat_critical_reading_avg_score': '379',
#   'sat_math_avg_score': '414',
#   'sat_writing_avg_score': '359'},
#  {'dbn': '29Q498',
#   'school_name': 'HUMANITIES & ARTS MAGNET HIGH SCHOOL',
#   'num_of_sat_test_takers': '62',
#   'sat_critical_reading_avg_score': '393',
#   'sat_math_avg_score': '381',
#   'sat_writing_avg_score': '377'},
#  {'dbn': '30Q286',
#   'school_name': "YOUNG WOMEN'S LEADERSHIP SCHOOL, ASTORIA",
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '30Q301',
#   'school_name': 'ACADEMY FOR CAREERS IN TELEVISION AND FILM',
#   'num_of_sat_test_takers': '98',
#   'sat_critical_reading_avg_score': '410',
#   'sat_math_avg_score': '440',
#   'sat_writing_avg_score': '405'},
#  {'dbn': '30Q445',
#   'school_name': 'WILLIAM CULLEN BRYANT HIGH SCHOOL',
#   'num_of_sat_test_takers': '395',
#   'sat_critical_reading_avg_score': '414',
#   'sat_math_avg_score': '449',
#   'sat_writing_avg_score': '412'},
#  {'dbn': '30Q450',
#   'school_name': 'LONG ISLAND CITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '392',
#   'sat_critical_reading_avg_score': '403',
#   'sat_math_avg_score': '420',
#   'sat_writing_avg_score': '395'},
#  {'dbn': '30Q501',
#   'school_name': 'FRANK SINATRA SCHOOL OF THE ARTS HIGH SCHOOL',
#   'num_of_sat_test_takers': '174',
#   'sat_critical_reading_avg_score': '504',
#   'sat_math_avg_score': '496',
#   'sat_writing_avg_score': '494'},
#  {'dbn': '30Q502',
#   'school_name': 'INFORMATION TECHNOLOGY HIGH SCHOOL',
#   'num_of_sat_test_takers': '148',
#   'sat_critical_reading_avg_score': '407',
#   'sat_math_avg_score': '434',
#   'sat_writing_avg_score': '398'},
#  {'dbn': '30Q555',
#   'school_name': 'NEWCOMERS HIGH SCHOOL',
#   'num_of_sat_test_takers': '143',
#   'sat_critical_reading_avg_score': '323',
#   'sat_math_avg_score': '475',
#   'sat_writing_avg_score': '329'},
#  {'dbn': '30Q575',
#   'school_name': 'ACADEMY OF AMERICAN STUDIES',
#   'num_of_sat_test_takers': '135',
#   'sat_critical_reading_avg_score': '487',
#   'sat_math_avg_score': '492',
#   'sat_writing_avg_score': '491'},
#  {'dbn': '30Q580',
#   'school_name': 'BACCALAUREATE SCHOOL FOR GLOBAL EDUCATION',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '524',
#   'sat_math_avg_score': '568',
#   'sat_writing_avg_score': '544'},
#  {'dbn': '31R047',
#   'school_name': 'CSI HIGH SCHOOL FOR INTERNATIONAL STUDIES',
#   'num_of_sat_test_takers': '137',
#   'sat_critical_reading_avg_score': '452',
#   'sat_math_avg_score': '451',
#   'sat_writing_avg_score': '450'},
#  {'dbn': '31R064',
#   'school_name': 'GAYNOR MCCOWN EXPEDITIONARY LEARNING SCHOOL',
#   'num_of_sat_test_takers': '61',
#   'sat_critical_reading_avg_score': '398',
#   'sat_math_avg_score': '412',
#   'sat_writing_avg_score': '385'},
#  {'dbn': '31R080',
#   'school_name': 'THE MICHAEL J. PETRIDES SCHOOL',
#   'num_of_sat_test_takers': '107',
#   'sat_critical_reading_avg_score': '472',
#   'sat_math_avg_score': '488',
#   'sat_writing_avg_score': '466'},
#  {'dbn': '31R440',
#   'school_name': 'NEW DORP HIGH SCHOOL',
#   'num_of_sat_test_takers': '391',
#   'sat_critical_reading_avg_score': '424',
#   'sat_math_avg_score': '437',
#   'sat_writing_avg_score': '416'},
#  {'dbn': '31R445',
#   'school_name': 'PORT RICHMOND HIGH SCHOOL',
#   'num_of_sat_test_takers': '271',
#   'sat_critical_reading_avg_score': '424',
#   'sat_math_avg_score': '438',
#   'sat_writing_avg_score': '417'},
#  {'dbn': '31R450',
#   'school_name': 'CURTIS HIGH SCHOOL',
#   'num_of_sat_test_takers': '375',
#   'sat_critical_reading_avg_score': '437',
#   'sat_math_avg_score': '435',
#   'sat_writing_avg_score': '429'},
#  {'dbn': '31R455',
#   'school_name': 'TOTTENVILLE HIGH SCHOOL',
#   'num_of_sat_test_takers': '807',
#   'sat_critical_reading_avg_score': '462',
#   'sat_math_avg_score': '486',
#   'sat_writing_avg_score': '470'},
#  {'dbn': '31R460',
#   'school_name': 'SUSAN E. WAGNER HIGH SCHOOL',
#   'num_of_sat_test_takers': '535',
#   'sat_critical_reading_avg_score': '455',
#   'sat_math_avg_score': '474',
#   'sat_writing_avg_score': '459'},
#  {'dbn': '31R470',
#   'school_name': 'CONCORD HIGH SCHOOL',
#   'num_of_sat_test_takers': '10',
#   'sat_critical_reading_avg_score': '466',
#   'sat_math_avg_score': '455',
#   'sat_writing_avg_score': '414'},
#  {'dbn': '31R600',
#   'school_name': 'RALPH R. MCKEE CAREER AND TECHNICAL EDUCATION HIGH SCHOOL',
#   'num_of_sat_test_takers': '94',
#   'sat_critical_reading_avg_score': '416',
#   'sat_math_avg_score': '422',
#   'sat_writing_avg_score': '397'},
#  {'dbn': '31R605',
#   'school_name': 'STATEN ISLAND TECHNICAL HIGH SCHOOL',
#   'num_of_sat_test_takers': '227',
#   'sat_critical_reading_avg_score': '635',
#   'sat_math_avg_score': '682',
#   'sat_writing_avg_score': '636'},
#  {'dbn': '31R607',
#   'school_name': 'YOUNG ADULT BOROUGH CENTER AT STATEN IS TECH HS',
#   'num_of_sat_test_takers': '10',
#   'sat_critical_reading_avg_score': '405',
#   'sat_math_avg_score': '375',
#   'sat_writing_avg_score': '370'},
#  {'dbn': '32K403',
#   'school_name': 'ACADEMY FOR ENVIRONMENTAL LEADERSHIP',
#   'num_of_sat_test_takers': '50',
#   'sat_critical_reading_avg_score': '380',
#   'sat_math_avg_score': '366',
#   'sat_writing_avg_score': '352'},
#  {'dbn': '32K545',
#   'school_name': 'EBC HIGH SCHOOL FOR PUBLIC SERVICE–BUSHWICK',
#   'num_of_sat_test_takers': '88',
#   'sat_critical_reading_avg_score': '384',
#   'sat_math_avg_score': '409',
#   'sat_writing_avg_score': '361'},
#  {'dbn': '32K549',
#   'school_name': 'BUSHWICK SCHOOL FOR SOCIAL JUSTICE',
#   'num_of_sat_test_takers': '75',
#   'sat_critical_reading_avg_score': '348',
#   'sat_math_avg_score': '353',
#   'sat_writing_avg_score': '334'},
#  {'dbn': '32K552',
#   'school_name': 'ACADEMY OF URBAN PLANNING',
#   'num_of_sat_test_takers': '67',
#   'sat_critical_reading_avg_score': '342',
#   'sat_math_avg_score': '364',
#   'sat_writing_avg_score': '354'},
#  {'dbn': '32K554',
#   'school_name': 'ALL CITY LEADERSHIP SECONDARY SCHOOL',
#   'num_of_sat_test_takers': '39',
#   'sat_critical_reading_avg_score': '428',
#   'sat_math_avg_score': '465',
#   'sat_writing_avg_score': '422'},
#  {'dbn': '32K556',
#   'school_name': 'BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCELLENCE',
#   'num_of_sat_test_takers': '23',
#   'sat_critical_reading_avg_score': '347',
#   'sat_math_avg_score': '358',
#   'sat_writing_avg_score': '350'},
#  {'dbn': '32K564',
#   'school_name': 'BUSHWICK COMMUNITY HIGH SCHOOL',
#   'num_of_sat_test_takers': '24',
#   'sat_critical_reading_avg_score': '359',
#   'sat_math_avg_score': '317',
#   'sat_writing_avg_score': '358'},
#  {'dbn': '75K371',
#   'school_name': 'P.S. 371 s LILLIAN L. RASHKIS',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75M035',
#   'school_name': 'P.S. 035',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75Q256',
#   'school_name': 'P.S. Q256',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75Q811',
#   'school_name': 'P.S. Q811',
#   'num_of_sat_test_takers': '32',
#   'sat_critical_reading_avg_score': '429',
#   'sat_math_avg_score': '444',
#   'sat_writing_avg_score': '433'},
#  {'dbn': '75R025',
#   'school_name': 'SOUTH RICHMOND HIGH SCHOOL I.S./P.S. 25',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75X012',
#   'school_name': 'P.S. X012 LEWIS AND CLARK SCHOOL',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '75X754',
#   'school_name': 'J. M. RAPPORT SCHOOL CAREER DEVELOPMENT',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '79M645',
#   'school_name': 'SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION',
#   'num_of_sat_test_takers': 's',
#   'sat_critical_reading_avg_score': 's',
#   'sat_math_avg_score': 's',
#   'sat_writing_avg_score': 's'},
#  {'dbn': '79Q950',
#   'school_name': 'GED PLUS s CITYWIDE',
#   'num_of_sat_test_takers': '8',
#   'sat_critical_reading_avg_score': '496',
#   'sat_math_avg_score': '400',
#   'sat_writing_avg_score': '426'},
#  {'dbn': '79X490',
#   'school_name': 'PHOENIX ACADEMY',
#   'num_of_sat_test_takers': '9',
#   'sat_critical_reading_avg_score': '367',
#   'sat_math_avg_score': '370',
#   'sat_writing_avg_score': '360'}]

# %%
import pandas as pd

# %%
df = pd.read_json(r.text)

# %%
df
# Out:
#         dbn  ... sat_writing_avg_score
# 0    01M292  ...                   363
# 1    01M448  ...                   366
# 2    01M450  ...                   370
# 3    01M458  ...                   359
# 4    01M509  ...                   384
# ..      ...  ...                   ...
# 473  75X012  ...                     s
# 474  75X754  ...                     s
# 475  79M645  ...                     s
# 476  79Q950  ...                   426
# 477  79X490  ...                   360
#
# [478 rows x 6 columns]

# %%
# Return df where all the rows does not contain 's'
df[df.sat_critical_reading_avg_score != 's']
# Out:
#         dbn  ... sat_writing_avg_score
# 0    01M292  ...                   363
# 1    01M448  ...                   366
# 2    01M450  ...                   370
# 3    01M458  ...                   359
# 4    01M509  ...                   384
# ..      ...  ...                   ...
# 466  32K556  ...                   350
# 467  32K564  ...                   358
# 471  75Q811  ...                   433
# 476  79Q950  ...                   426
# 477  79X490  ...                   360
#
# [421 rows x 6 columns]

# %%
# Making columns easier to work with by removing all spaces, replacing with underscores, & lowering all chars.

def standard_cols(df):
    df.columns = [x.lower() for x in df.columns]
    df.columns = df.columns.str.replace(' ', '_')
    return df

# %%
payload = {'$limit': 10, '$$app_token': ''}
r = requests.get('', params=payload)

# %% [markdown]
# ## Web Scraping
#
# Sends request to server for HTML document. You need to manually parse the HTML document to find the data

# %%
import requests

# %%
# Do Not Run
r = requests.get('https//basketball-reference.com/teams/PHI/2022.html')

# %%
# HTML Parser
from bs4 import BeautifulSoup

# %%
# Turn the raw HTML into a soup object
soup = BeautifulSoup(r.text, 'html.parser')

# %%
found_table = soup.findAll('div', attrs={'id': 'div_roster'})

# %%
found_table = soup.findAll('table')

# %%
roster_table = found_table[0]

# %%
player_rows = roster_table('tr')

# %%
# Delete rows you don't need
del player_rows[0]

# %%
# List comprehension to extract all the text data from each ID element
extracted_text = [ele.text for ele in player_rows[0].find_all('td')]

# %%
keys = []

# %%
player_dict = []

for player in player_rows:
    found_rows = player.find_all('td')
    stripped_text = [ele.text for ele in found_rows]
    player_dict.append(dict(zip(keys, stripped_text)))

# %%
df = pd.DataFrame(player_dict)

# %% [markdown]
# Selenium allows us to open up chrome in the background. It lets us use Python to contol code. Control web browsers using Python
#
# Tool to parse HTML to execute their own JS

# %%
import selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

# %% [markdown]
# # 3/22/22

# %%
import requests
import pandas as pd
import sqlite3
import json
import sqlalchemy
from sqlalchemy import create_engine, select, MetaData, Table, and_
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.inspection import inspect

# %%
payload = {'$limit':25}
r = requests.get('https://data.cityofnewyork.us/resource/erm2-nwe9.json', params=payload)

# %%
len(r.json())
# Out:
# 25

# %%
r.json()
# Out:
# [{'unique_key': '53705459',
#   'created_date': '2022-03-22T02:08:27.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Commercial Overnight Parking',
#   'location_type': 'Street/Sidewalk',
#   'status': 'In Progress',
#   'community_board': '0 Unspecified',
#   'borough': 'Unspecified',
#   'x_coordinate_state_plane': '989197',
#   'y_coordinate_state_plane': '167341',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'Unspecified',
#   'latitude': '40.62598751782671',
#   'longitude': '-73.98217866639271',
#   'location': {'latitude': '40.62598751782671',
#    'longitude': '-73.98217866639271',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '16867',
#   ':@computed_region_f5dn_yrer': '2',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '18',
#   ':@computed_region_sbqj_enih': '39'},
#  {'unique_key': '53706740',
#   'created_date': '2022-03-22T02:07:44.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'status': 'In Progress',
#   'community_board': '0 Unspecified',
#   'borough': 'Unspecified',
#   'x_coordinate_state_plane': '988748',
#   'y_coordinate_state_plane': '194561',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'Unspecified',
#   'latitude': '40.700700626190894',
#   'longitude': '-73.9837780082792',
#   'location': {'latitude': '40.700700626190894',
#    'longitude': '-73.9837780082792',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '16865',
#   ':@computed_region_f5dn_yrer': '68',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '48',
#   ':@computed_region_sbqj_enih': '54'},
#  {'unique_key': '53711602',
#   'created_date': '2022-03-22T02:07:35.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10469',
#   'incident_address': '3313 WICKHAM AVENUE',
#   'street_name': 'WICKHAM AVENUE',
#   'cross_street_1': 'GIVAN AVENUE',
#   'cross_street_2': 'TILLOTSON AVENUE',
#   'intersection_street_1': 'GIVAN AVENUE',
#   'intersection_street_2': 'TILLOTSON AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'landmark': 'WICKHAM AVENUE',
#   'status': 'In Progress',
#   'community_board': '12 BRONX',
#   'bbl': '2047510028',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1028166',
#   'y_coordinate_state_plane': '258691',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.87661209369002',
#   'longitude': '-73.84119827333907',
#   'location': {'latitude': '40.87661209369002',
#    'longitude': '-73.84119827333907',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '11607',
#   ':@computed_region_f5dn_yrer': '29',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '2',
#   ':@computed_region_sbqj_enih': '30'},
#  {'unique_key': '53707935',
#   'created_date': '2022-03-22T02:07:21.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Hydrant',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11355',
#   'incident_address': '149-55 DELAWARE AVENUE',
#   'street_name': 'DELAWARE AVENUE',
#   'cross_street_1': '149 STREET',
#   'cross_street_2': 'MURRAY STREET',
#   'intersection_street_1': '149 STREET',
#   'intersection_street_2': 'MURRAY STREET',
#   'address_type': 'ADDRESS',
#   'city': 'FLUSHING',
#   'landmark': 'DELAWARE AVENUE',
#   'status': 'In Progress',
#   'community_board': '07 QUEENS',
#   'bbl': '4054080041',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1035984',
#   'y_coordinate_state_plane': '215316',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.75751781913085',
#   'longitude': '-73.81326256129258',
#   'location': {'latitude': '40.75751781913085',
#    'longitude': '-73.81326256129258',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '14190',
#   ':@computed_region_f5dn_yrer': '22',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '3',
#   ':@computed_region_sbqj_enih': '67'},
#  {'unique_key': '53704329',
#   'created_date': '2022-03-22T02:07:12.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '11201',
#   'incident_address': '177 SANDS STREET',
#   'street_name': 'SANDS STREET',
#   'cross_street_1': 'BQE WESTBOUND ENTRANCE SANDS ST',
#   'cross_street_2': 'BIKE PATH',
#   'intersection_street_1': 'BQE WESTBOUND ENTRANCE SANDS ST',
#   'intersection_street_2': 'BIKE PATH',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'landmark': 'SANDS STREET',
#   'status': 'In Progress',
#   'community_board': '02 BROOKLYN',
#   'bbl': '3000680001',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '989064',
#   'y_coordinate_state_plane': '194225',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.69977821848639',
#   'longitude': '-73.9826385976589',
#   'location': {'latitude': '40.69977821848639',
#    'longitude': '-73.9826385976589',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '16865',
#   ':@computed_region_f5dn_yrer': '68',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '48',
#   ':@computed_region_sbqj_enih': '54'},
#  {'unique_key': '53704341',
#   'created_date': '2022-03-22T02:06:17.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '11235',
#   'incident_address': '501 BRIGHTWATER COURT',
#   'street_name': 'BRIGHTWATER COURT',
#   'cross_street_1': 'BRIGHTON    5 STREET',
#   'cross_street_2': 'BRIGHTON    6 STREET',
#   'intersection_street_1': 'BRIGHTON    5 STREET',
#   'intersection_street_2': 'BRIGHTON    6 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'landmark': 'BRIGHTWATER COURT',
#   'status': 'In Progress',
#   'community_board': '13 BROOKLYN',
#   'bbl': '3086890097',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '994823',
#   'y_coordinate_state_plane': '149049',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.57577476680645',
#   'longitude': '-73.9619399004256',
#   'location': {'latitude': '40.57577476680645',
#    'longitude': '-73.9619399004256',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '13826',
#   ':@computed_region_f5dn_yrer': '21',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '15',
#   ':@computed_region_sbqj_enih': '35'},
#  {'unique_key': '53703060',
#   'created_date': '2022-03-22T02:05:32.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Food Establishment',
#   'descriptor': 'Rodents/Insects/Garbage',
#   'location_type': 'Restaurant/Bar/Deli/Bakery',
#   'incident_zip': '10065',
#   'incident_address': '696 MADISON AVENUE',
#   'street_name': 'MADISON AVENUE',
#   'cross_street_1': 'EAST   62 STREET',
#   'cross_street_2': 'EAST   63 STREET',
#   'intersection_street_1': 'EAST   62 STREET',
#   'intersection_street_2': 'EAST   63 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'landmark': 'MADISON AVENUE',
#   'status': 'In Progress',
#   'community_board': '08 MANHATTAN',
#   'bbl': '1013770016',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '992595',
#   'y_coordinate_state_plane': '218248',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7657128194109',
#   'longitude': '-73.96987446319872',
#   'location': {'latitude': '40.7657128194109',
#    'longitude': '-73.96987446319872',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '10090',
#   ':@computed_region_f5dn_yrer': '23',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '51',
#   ':@computed_region_sbqj_enih': '11'},
#  {'unique_key': '53703088',
#   'created_date': '2022-03-22T02:04:39.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10026',
#   'incident_address': '32 WEST  111 STREET',
#   'street_name': 'WEST  111 STREET',
#   'cross_street_1': '111 STREET OLD TIMERS WAY',
#   'cross_street_2': 'LENOX AVENUE',
#   'intersection_street_1': '111 STREET OLD TIMERS WAY',
#   'intersection_street_2': 'LENOX AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'landmark': 'WEST  111 STREET',
#   'status': 'In Progress',
#   'community_board': '10 MANHATTAN',
#   'bbl': '1015940054',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '998099',
#   'y_coordinate_state_plane': '230005',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.79797575098443',
#   'longitude': '-73.94998073391412',
#   'location': {'latitude': '40.79797575098443',
#    'longitude': '-73.94998073391412',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '12423',
#   ':@computed_region_f5dn_yrer': '18',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '36',
#   ':@computed_region_sbqj_enih': '18'},
#  {'unique_key': '53710428',
#   'created_date': '2022-03-22T02:03:52.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Sidewalk',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10456',
#   'incident_address': '1064 FRANKLIN AVENUE',
#   'street_name': 'FRANKLIN AVENUE',
#   'cross_street_1': '3 AVENUE',
#   'cross_street_2': 'EAST  166 STREET',
#   'intersection_street_1': '3 AVENUE',
#   'intersection_street_2': 'EAST  166 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'landmark': 'FRANKLIN AVENUE',
#   'status': 'In Progress',
#   'community_board': '03 BRONX',
#   'bbl': '2026070032',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1009979',
#   'y_coordinate_state_plane': '240662',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.82719962490528',
#   'longitude': '-73.907032197941',
#   'location': {'latitude': '40.82719962490528',
#    'longitude': '-73.907032197941',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '10934',
#   ':@computed_region_f5dn_yrer': '34',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '42',
#   ':@computed_region_sbqj_enih': '25'},
#  {'unique_key': '53703126',
#   'created_date': '2022-03-22T02:03:49.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Vehicle',
#   'descriptor': 'Engine Idling',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11365',
#   'incident_address': '175 STREET',
#   'street_name': '175 STREET',
#   'cross_street_1': '175 STREET',
#   'cross_street_2': 'BOOTH MEMORIAL AVENUE',
#   'intersection_street_1': '175 STREET',
#   'intersection_street_2': 'BOOTH MEMORIAL AVENUE',
#   'address_type': 'INTERSECTION',
#   'status': 'In Progress',
#   'community_board': '11 QUEENS',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1041135',
#   'y_coordinate_state_plane': '209504',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.74153374855259',
#   'longitude': '-73.79471889981325',
#   'location': {'latitude': '40.74153374855259',
#    'longitude': '-73.79471889981325',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '14507',
#   ':@computed_region_f5dn_yrer': '26',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '3',
#   ':@computed_region_sbqj_enih': '69'},
#  {'unique_key': '53711625',
#   'created_date': '2022-03-22T02:02:49.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Street/Sidewalk',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11385',
#   'incident_address': '71-05 67 PLACE',
#   'street_name': '67 PLACE',
#   'cross_street_1': 'CENTRAL AVENUE',
#   'cross_street_2': 'MYRTLE AVENUE',
#   'intersection_street_1': 'CENTRAL AVENUE',
#   'intersection_street_2': 'MYRTLE AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'RIDGEWOOD',
#   'landmark': '67 PLACE',
#   'status': 'In Progress',
#   'community_board': '05 QUEENS',
#   'bbl': '4036810003',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1015810',
#   'y_coordinate_state_plane': '195439',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.70305539295501',
#   'longitude': '-73.88617512587406',
#   'location': {'latitude': '40.70305539295501',
#    'longitude': '-73.88617512587406',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '15310',
#   ':@computed_region_f5dn_yrer': '54',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '34',
#   ':@computed_region_sbqj_enih': '62'},
#  {'unique_key': '53703065',
#   'created_date': '2022-03-22T02:02:04.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Hydrant',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11372',
#   'incident_address': '34-24 72 STREET',
#   'street_name': '72 STREET',
#   'cross_street_1': '34 AVENUE',
#   'cross_street_2': '35 AVENUE',
#   'intersection_street_1': '34 AVENUE',
#   'intersection_street_2': '35 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'JACKSON HEIGHTS',
#   'landmark': '72 STREET',
#   'status': 'In Progress',
#   'community_board': '03 QUEENS',
#   'bbl': '4012580016',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1013579',
#   'y_coordinate_state_plane': '213149',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.7516726673045',
#   'longitude': '-73.89414429652578',
#   'location': {'latitude': '40.7516726673045',
#    'longitude': '-73.89414429652578',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '14783',
#   ':@computed_region_f5dn_yrer': '65',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '5',
#   ':@computed_region_sbqj_enih': '73'},
#  {'unique_key': '53711574',
#   'created_date': '2022-03-22T02:01:20.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Hydrant',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11373',
#   'incident_address': '92-07 53 AVENUE',
#   'street_name': '53 AVENUE',
#   'cross_street_1': '92 STREET',
#   'cross_street_2': '94 STREET',
#   'intersection_street_1': '92 STREET',
#   'intersection_street_2': '94 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'ELMHURST',
#   'landmark': '53 AVENUE',
#   'status': 'In Progress',
#   'community_board': '04 QUEENS',
#   'bbl': '4018680054',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1020109',
#   'y_coordinate_state_plane': '208463',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.73878671476362',
#   'longitude': '-73.87060090679695',
#   'location': {'latitude': '40.73878671476362',
#    'longitude': '-73.87060090679695',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '14784',
#   ':@computed_region_f5dn_yrer': '66',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '5',
#   ':@computed_region_sbqj_enih': '68'},
#  {'unique_key': '53707956',
#   'created_date': '2022-03-22T02:00:03.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10459',
#   'incident_address': '1255 LONGFELLOW AVENUE',
#   'street_name': 'LONGFELLOW AVENUE',
#   'cross_street_1': 'WEST FARMS ROAD',
#   'cross_street_2': 'FREEMAN STREET',
#   'intersection_street_1': 'WEST FARMS ROAD',
#   'intersection_street_2': 'FREEMAN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'landmark': 'LONGFELLOW AVENUE',
#   'status': 'In Progress',
#   'community_board': '03 BRONX',
#   'bbl': '2029930046',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1015227',
#   'y_coordinate_state_plane': '241388',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.82917543940849',
#   'longitude': '-73.8880660202654',
#   'location': {'latitude': '40.82917543940849',
#    'longitude': '-73.8880660202654',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '10937',
#   ':@computed_region_f5dn_yrer': '34',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '43',
#   ':@computed_region_sbqj_enih': '25'},
#  {'unique_key': '53710376',
#   'created_date': '2022-03-22T01:59:41.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Curb Condition',
#   'descriptor': 'Broken Curb',
#   'location_type': 'Sidewalk',
#   'incident_zip': '11220',
#   'incident_address': '536 BAYRIDGE AVENUE',
#   'street_name': 'BAYRIDGE AVENUE',
#   'cross_street_1': '5 AVENUE',
#   'cross_street_2': 'VISTA PLACE',
#   'intersection_street_1': '5 AVENUE',
#   'intersection_street_2': 'VISTA PLACE',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'landmark': 'BAY RIDGE AVENUE',
#   'status': 'In Progress',
#   'community_board': '10 BROOKLYN',
#   'bbl': '3058740024',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '978682',
#   'y_coordinate_state_plane': '169905',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.6330247882993',
#   'longitude': '-74.02006057195946',
#   'location': {'latitude': '40.6330247882993',
#    'longitude': '-74.02006057195946',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '18180',
#   ':@computed_region_f5dn_yrer': '10',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '44',
#   ':@computed_region_sbqj_enih': '41'},
#  {'unique_key': '53703071',
#   'created_date': '2022-03-22T01:58:43.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Posted Parking Sign Violation',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11373',
#   'incident_address': '53-01 94 STREET',
#   'street_name': '94 STREET',
#   'cross_street_1': '53 AVENUE',
#   'cross_street_2': '54 AVENUE',
#   'intersection_street_1': '53 AVENUE',
#   'intersection_street_2': '54 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'ELMHURST',
#   'landmark': '94 STREET',
#   'status': 'In Progress',
#   'community_board': '04 QUEENS',
#   'bbl': '4018930046',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1020644',
#   'y_coordinate_state_plane': '208577',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.73909743076647',
#   'longitude': '-73.86866971719114',
#   'location': {'latitude': '40.73909743076647',
#    'longitude': '-73.86866971719114',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '14784',
#   ':@computed_region_f5dn_yrer': '66',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '5',
#   ':@computed_region_sbqj_enih': '68'},
#  {'unique_key': '53711569',
#   'created_date': '2022-03-22T01:57:55.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Hydrant',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11372',
#   'incident_address': '34-20 71 STREET',
#   'street_name': '71 STREET',
#   'cross_street_1': '34 AVENUE',
#   'cross_street_2': '35 AVENUE',
#   'intersection_street_1': '34 AVENUE',
#   'intersection_street_2': '35 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'JACKSON HEIGHTS',
#   'landmark': '71 STREET',
#   'status': 'In Progress',
#   'community_board': '03 QUEENS',
#   'bbl': '4012570015',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1013319',
#   'y_coordinate_state_plane': '213134',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.75163235468768',
#   'longitude': '-73.89508276555817',
#   'location': {'latitude': '40.75163235468768',
#    'longitude': '-73.89508276555817',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '14783',
#   ':@computed_region_f5dn_yrer': '65',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '5',
#   ':@computed_region_sbqj_enih': '73'},
#  {'unique_key': '53710424',
#   'created_date': '2022-03-22T01:55:13.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Blocked Hydrant',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11370',
#   'incident_address': '31-48 78 STREET',
#   'street_name': '78 STREET',
#   'cross_street_1': '31 AVENUE',
#   'cross_street_2': '32 AVENUE',
#   'intersection_street_1': '31 AVENUE',
#   'intersection_street_2': '32 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'EAST ELMHURST',
#   'landmark': '78 STREET',
#   'status': 'In Progress',
#   'community_board': '03 QUEENS',
#   'bbl': '4011480032',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1014874',
#   'y_coordinate_state_plane': '215152',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.75716599887578',
#   'longitude': '-73.88946119950806',
#   'location': {'latitude': '40.75716599887578',
#    'longitude': '-73.88946119950806',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '14781',
#   ':@computed_region_f5dn_yrer': '65',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '5',
#   ':@computed_region_sbqj_enih': '73'},
#  {'unique_key': '53705535',
#   'created_date': '2022-03-22T01:55:13.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Indoor Sewage',
#   'descriptor': 'Sewage Leak',
#   'location_type': '1-2 Family Mixed Use Building',
#   'incident_zip': '11694',
#   'incident_address': '188 BEACH  115 STREET',
#   'street_name': 'BEACH  115 STREET',
#   'cross_street_1': 'OCEAN PROMENADE',
#   'cross_street_2': 'ROCKAWAY BEACH BOULEVARD',
#   'intersection_street_1': 'OCEAN PROMENADE',
#   'intersection_street_2': 'ROCKAWAY BEACH BOULEVARD',
#   'address_type': 'ADDRESS',
#   'city': 'FAR ROCKAWAY',
#   'landmark': 'BEACH  115 STREET',
#   'status': 'In Progress',
#   'community_board': '14 QUEENS',
#   'bbl': '4161870077',
#   'borough': 'QUEENS',
#   'x_coordinate_state_plane': '1029797',
#   'y_coordinate_state_plane': '150520',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'QUEENS',
#   'latitude': '40.57970167090906',
#   'longitude': '-73.83603270245536',
#   'location': {'latitude': '40.57970167090906',
#    'longitude': '-73.83603270245536',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '20532',
#   ':@computed_region_f5dn_yrer': '51',
#   ':@computed_region_yeji_bk3q': '3',
#   ':@computed_region_92fq_4b7q': '41',
#   ':@computed_region_sbqj_enih': '58'},
#  {'unique_key': '53710473',
#   'created_date': '2022-03-22T01:53:21.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Street/Sidewalk',
#   'descriptor': 'Loud Talking',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10023',
#   'incident_address': '285 COLUMBUS AVENUE',
#   'street_name': 'COLUMBUS AVENUE',
#   'cross_street_1': 'WEST   73 STREET',
#   'cross_street_2': 'WEST   74 STREET',
#   'intersection_street_1': 'WEST   73 STREET',
#   'intersection_street_2': 'WEST   74 STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'landmark': 'COLUMBUS AVENUE',
#   'status': 'In Progress',
#   'community_board': '07 MANHATTAN',
#   'bbl': '1011260001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '990310',
#   'y_coordinate_state_plane': '222841',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.77832126594149',
#   'longitude': '-73.9781191948665',
#   'location': {'latitude': '40.77832126594149',
#    'longitude': '-73.9781191948665',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '12420',
#   ':@computed_region_f5dn_yrer': '20',
#   ':@computed_region_yeji_bk3q': '4',
#   ':@computed_region_92fq_4b7q': '19',
#   ':@computed_region_sbqj_enih': '12'},
#  {'unique_key': '53711458',
#   'created_date': '2022-03-22T01:53:14.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Abandoned Vehicle',
#   'descriptor': 'With License Plate',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11239',
#   'incident_address': '526 SCHROEDERS AVENUE',
#   'street_name': 'SCHROEDERS AVENUE',
#   'cross_street_1': 'ELTON STREET',
#   'cross_street_2': 'ESSEX STREET',
#   'intersection_street_1': 'ELTON STREET',
#   'intersection_street_2': 'ESSEX STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'landmark': 'SCHROEDERS AVENUE',
#   'status': 'In Progress',
#   'community_board': '05 BROOKLYN',
#   'bbl': '3044527505',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1019662',
#   'y_coordinate_state_plane': '177984',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.655130846729016',
#   'longitude': '-73.87237417153659',
#   'location': {'latitude': '40.655130846729016',
#    'longitude': '-73.87237417153659',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '17215',
#   ':@computed_region_f5dn_yrer': '45',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '25',
#   ':@computed_region_sbqj_enih': '47'},
#  {'unique_key': '53706724',
#   'created_date': '2022-03-22T01:53:07.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Posted Parking Sign Violation',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11239',
#   'incident_address': '516 SCHROEDERS AVENUE',
#   'street_name': 'SCHROEDERS AVENUE',
#   'cross_street_1': 'ASHFORD STREET',
#   'cross_street_2': 'ELTON STREET',
#   'intersection_street_1': 'ASHFORD STREET',
#   'intersection_street_2': 'ELTON STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'landmark': 'SCHROEDERS AVENUE',
#   'status': 'In Progress',
#   'community_board': '05 BROOKLYN',
#   'bbl': '3044520423',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1019436',
#   'y_coordinate_state_plane': '177854',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.65477492642719',
#   'longitude': '-73.87318935891275',
#   'location': {'latitude': '40.65477492642719',
#    'longitude': '-73.87318935891275',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '17215',
#   ':@computed_region_f5dn_yrer': '45',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '25',
#   ':@computed_region_sbqj_enih': '47'},
#  {'unique_key': '53703227',
#   'created_date': '2022-03-22T01:52:40.000',
#   'agency': 'DCA',
#   'agency_name': 'Department of Consumer Affairs',
#   'complaint_type': 'Consumer Complaint',
#   'descriptor': 'Tow Truck Company',
#   'location_type': 'Business',
#   'incident_zip': '11213',
#   'incident_address': '1775 PACIFIC STREET',
#   'street_name': 'PACIFIC STREET',
#   'cross_street_1': 'SCHENECTADY AVENUE',
#   'cross_street_2': 'REVEREND TIMOTHY WRIGHT WAY',
#   'intersection_street_1': 'SCHENECTADY AVENUE',
#   'intersection_street_2': 'REVEREND TIMOTHY WRIGHT WAY',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'landmark': 'PACIFIC STREET',
#   'status': 'In Progress',
#   'community_board': '08 BROOKLYN',
#   'bbl': '3013360064',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '1003287',
#   'y_coordinate_state_plane': '185809',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.6766590705356',
#   'longitude': '-73.93136799464132',
#   'location': {'latitude': '40.6766590705356',
#    'longitude': '-73.93136799464132',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '17615',
#   ':@computed_region_f5dn_yrer': '16',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '49',
#   ':@computed_region_sbqj_enih': '49'},
#  {'unique_key': '53706763',
#   'created_date': '2022-03-22T01:52:11.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '11209',
#   'incident_address': '443 74 STREET',
#   'street_name': '74 STREET',
#   'cross_street_1': 'PATROLMAN ARTHUR LOEWE WAY',
#   'cross_street_2': '5 AVENUE',
#   'intersection_street_1': 'PATROLMAN ARTHUR LOEWE WAY',
#   'intersection_street_2': '5 AVENUE',
#   'address_type': 'ADDRESS',
#   'city': 'BROOKLYN',
#   'landmark': '74 STREET',
#   'status': 'In Progress',
#   'resolution_description': 'Your complaint has been received by the Police Department and additional information will be available later.',
#   'resolution_action_updated_date': '2022-03-22T01:54:41.000',
#   'community_board': '10 BROOKLYN',
#   'bbl': '3059190060',
#   'borough': 'BROOKLYN',
#   'x_coordinate_state_plane': '977682',
#   'y_coordinate_state_plane': '169160',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BROOKLYN',
#   'latitude': '40.630979236028296',
#   'longitude': '-74.02366267934529',
#   'location': {'latitude': '40.630979236028296',
#    'longitude': '-74.02366267934529',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '17216',
#   ':@computed_region_f5dn_yrer': '10',
#   ':@computed_region_yeji_bk3q': '2',
#   ':@computed_region_92fq_4b7q': '44',
#   ':@computed_region_sbqj_enih': '41'},
#  {'unique_key': '53704345',
#   'created_date': '2022-03-22T01:51:26.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Talking',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10459',
#   'incident_address': '1255 LONGFELLOW AVENUE',
#   'street_name': 'LONGFELLOW AVENUE',
#   'cross_street_1': 'WEST FARMS ROAD',
#   'cross_street_2': 'FREEMAN STREET',
#   'intersection_street_1': 'WEST FARMS ROAD',
#   'intersection_street_2': 'FREEMAN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'BRONX',
#   'landmark': 'LONGFELLOW AVENUE',
#   'status': 'In Progress',
#   'community_board': '03 BRONX',
#   'bbl': '2029930046',
#   'borough': 'BRONX',
#   'x_coordinate_state_plane': '1015227',
#   'y_coordinate_state_plane': '241388',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'BRONX',
#   'latitude': '40.82917543940849',
#   'longitude': '-73.8880660202654',
#   'location': {'latitude': '40.82917543940849',
#    'longitude': '-73.8880660202654',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#   ':@computed_region_efsh_h5xi': '10937',
#   ':@computed_region_f5dn_yrer': '34',
#   ':@computed_region_yeji_bk3q': '5',
#   ':@computed_region_92fq_4b7q': '43',
#   ':@computed_region_sbqj_enih': '25'}]

# %%
# Create a raw data table to be safe

# Create our DataBase if it doesn't exist, & connect to it
# Standard syntax
# stores result of function call
con = sqlite3.connect('calls.db')

# %%
# Store result of the cursor method into cur
# Allow us to execute SQL to our DataBase
cur = con.cursor()

# %%
sql_create_raw_json_table = '''CREATE TABLE raw_json(
                                id INTEGER PRIMARY KEY AUTOINCREMENT,
                                raw_text text
                            )'''

# %%
cur.execute(sql_create_raw_json_table)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9816/2539233158.py in <module>
# ----> 1 cur.execute(sql_create_raw_json_table)
#
# OperationalError: table raw_json already exists

# %%
# Makes change permanent
con.commit()

# %%
# For each row in our response, stringify and place into tuple, and place into a list
# Does the same exact thing as the code block below
[(json.dumps(x),) for x in r.json()]

# %%
# json.Loads(some_json) - takes string json and jsonifies it
# json.dumps(some_json) - takes json and stringifies it
# Convert every row of json into string to place into DataBase
list_of_strings = []
for row in r.json():
    list_of_strings.append(json.dumps(row))

list_of_strings

list_of_tuples = [] 
for row in list_of_strings:
    list_of_tuples.append((row,))
list_of_tuples

# %%
# Explicitly tell SQL where to put the values of l_o_t (into raw text)
# (?) escaping - like a rigid f'' string - find the parameter in the value given
# You will leave yourself open to SQL injection if you don't escape
'''
cur.executemany('INSERT INTO {tablename} (raw_text) VALUES (escaping)', list_of_strings)
'''

cur.executemany('INSERT INTO raw_json (raw_text) VALUES (?)', list_of_tuples)

# %%
con.commit()

# %%
con.close()

# %%
con = sqlite3.connect('calls.db')
cur = con.cursor()

# %%
cur.execute('select * from raw_json')

# %%
x = cur.fetchall()

# %%
for row in x:
    print(row)

# %%
con.close()

# %% [markdown]
# Build out API

# %%
# This function is going to get us our raw data
# Places rows in a list

def get_raw_data():
    con = sqlite3.connect('calls.db')
    cur = con.cursor()
    list_of_rows = []
    for row in cur.execute('SELECT * from raw_json'):
        list_of_rows.append(row)
    con.close()
    return list_of_rows

# %%
raw_data = get_raw_data()

# %%
# Use raw json table to get new table of key-values I care about
# Convert from raw jsons to dictionaries

kvs_i_care_about = ['created_date','agency','agency_name','complaint_type','descriptor',
                   'location_type','incident_zip','incident_address','borough']

# %%
def data_extractor(list_of_tuples, list_of_keys):
    # Create empty list to store unpacked dictionaries
    list_of_relevant_info = []
    # Extract json from tuple pair by unpacking
    # x: id, y: {raw_json}
    for x, y in list_of_tuples:
        # Set up a temporary dictionary to hold pruned k-v pairs- it's reset on every iterative loop
        temp_dict = {}
        # We need to jsonify our string
        parsed_json = json.loads(y)
        # Iterate over the key-value pairings in our dictionary
        # Unpack the JSON, storing keys in k, values in v
        # Only want to retain the key-values I care about 
        for k, v in parsed_json.items():
            # Check if it matches the string in the kvs_i_care_about
            if k in list_of_keys:
                # If it matches, store the key-value pairing
                temp_dict[k] = v
            # Append to the list & do this for every k-v pairings that match
        list_of_relevant_info.append(temp_dict)
    return list_of_relevant_info

# %%
data_extractor(raw_data, kvs_i_care_about)
# Out:
# [{'created_date': '2022-03-21T01:59:35.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Blocked Driveway',
#   'descriptor': 'No Access',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11207',
#   'incident_address': '2869 FULTON STREET',
#   'borough': 'BROOKLYN'},
#  {'created_date': '2022-03-21T01:59:35.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Blocked Driveway',
#   'descriptor': 'No Access',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11207',
#   'incident_address': '2869 FULTON STREET',
#   'borough': 'BROOKLYN'},
#  {'created_date': '2022-03-21T01:59:05.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Vehicle',
#   'descriptor': 'Engine Idling',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11373',
#   'incident_address': '92-01 51 AVENUE',
#   'borough': 'QUEENS'},
#  {'created_date': '2022-03-21T01:58:34.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Television',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10030',
#   'incident_address': '112 WEST  138 STREET',
#   'borough': 'MANHATTAN'},
#  {'created_date': '2022-03-21T01:57:09.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Street Sign - Missing',
#   'descriptor': 'Other/Unknown',
#   'location_type': 'Street',
#   'incident_zip': '10029',
#   'incident_address': '1501 LEXINGTON AVENUE',
#   'borough': 'MANHATTAN'},
#  {'created_date': '2022-03-21T01:56:46.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Talking',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10009',
#   'incident_address': '725 EAST    5 STREET',
#   'borough': 'MANHATTAN'},
#  {'created_date': '2022-03-21T01:55:36.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Vehicle',
#   'descriptor': 'Engine Idling',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11419',
#   'incident_address': 'ATLANTIC AVENUE',
#   'borough': 'QUEENS'},
#  {'created_date': '2022-03-21T01:53:53.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Talking',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10039',
#   'incident_address': '271 WEST  146 STREET',
#   'borough': 'MANHATTAN'},
#  {'created_date': '2022-03-21T01:53:18.000',
#   'agency': 'DCA',
#   'agency_name': 'Department of Consumer Affairs',
#   'complaint_type': 'Consumer Complaint',
#   'descriptor': 'Mobile Food Vendor',
#   'location_type': 'Business',
#   'incident_zip': '10001',
#   'incident_address': '651 WEST   33 STREET',
#   'borough': 'MANHATTAN'},
#  {'created_date': '2022-03-21T01:52:53.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Vehicle',
#   'descriptor': 'Car/Truck Music',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10456',
#   'incident_address': '1254 SHERMAN AVENUE',
#   'borough': 'BRONX'},
#  {'created_date': '2022-03-21T01:52:38.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '11374',
#   'incident_address': '99-65 64 ROAD',
#   'borough': 'QUEENS'},
#  {'created_date': '2022-03-21T01:52:37.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Parking Permit Improper Use',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11370',
#   'incident_address': '31-20 82 STREET',
#   'borough': 'QUEENS'},
#  {'created_date': '2022-03-21T01:52:26.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '11213',
#   'incident_address': '86 UTICA AVENUE',
#   'borough': 'BROOKLYN'},
#  {'created_date': '2022-03-21T01:50:08.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Food Establishment',
#   'descriptor': 'Kitchen/Food Prep Area',
#   'location_type': 'Restaurant/Bar/Deli/Bakery',
#   'incident_zip': '10010',
#   'incident_address': '64 WEST   22 STREET',
#   'borough': 'MANHATTAN'},
#  {'created_date': '2022-03-21T01:49:45.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Street/Sidewalk',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10456',
#   'incident_address': '1254 SHERMAN AVENUE',
#   'borough': 'BRONX'},
#  {'created_date': '2022-03-21T01:48:02.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Vehicle',
#   'descriptor': 'Engine Idling',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11101',
#   'incident_address': '2-01 51 AVENUE',
#   'borough': 'QUEENS'},
#  {'created_date': '2022-03-21T01:47:51.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10457',
#   'incident_address': '1880 VALENTINE AVENUE',
#   'borough': 'BRONX'},
#  {'created_date': '2022-03-21T01:47:45.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Commercial',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Club/Bar/Restaurant',
#   'incident_zip': '11103',
#   'incident_address': '28-26 STEINWAY STREET',
#   'borough': 'QUEENS'},
#  {'created_date': '2022-03-21T01:47:14.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10451',
#   'incident_address': '890 COURTLANDT AVENUE',
#   'borough': 'BRONX'},
#  {'created_date': '2022-03-21T01:46:39.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Posted Parking Sign Violation',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11211',
#   'incident_address': '106 MARCY AVENUE',
#   'borough': 'BROOKLYN'},
#  {'created_date': '2022-03-21T01:46:06.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Blocked Driveway',
#   'descriptor': 'No Access',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11355',
#   'incident_address': '132-46 41 AVENUE',
#   'borough': 'QUEENS'},
#  {'created_date': '2022-03-21T01:45:59.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Commercial',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Store/Commercial',
#   'incident_zip': '10458',
#   'incident_address': '2645 BRIGGS AVENUE',
#   'borough': 'BRONX'},
#  {'created_date': '2022-03-21T01:45:54.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Loud Music/Party',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '10040',
#   'incident_address': '11 HILLSIDE AVENUE',
#   'borough': 'MANHATTAN'},
#  {'created_date': '2022-03-21T01:45:21.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Commercial Overnight Parking',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '11235',
#   'incident_address': '117 BEAUMONT STREET',
#   'borough': 'BROOKLYN'},
#  {'created_date': '2022-03-21T01:45:13.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Residential',
#   'descriptor': 'Banging/Pounding',
#   'location_type': 'Residential Building/House',
#   'incident_zip': '11372',
#   'incident_address': '35-43 84 STREET',
#   'borough': 'QUEENS'}]

# %%
df = pd.DataFrame(data_extractor(raw_data))

# %%
df
# Out:
#                created_date agency                              agency_name  \
# 0   2022-03-21T01:59:35.000   NYPD          New York City Police Department
# 1   2022-03-21T01:59:35.000   NYPD          New York City Police Department
# 2   2022-03-21T01:59:05.000   NYPD          New York City Police Department
# 3   2022-03-21T01:58:34.000   NYPD          New York City Police Department
# 4   2022-03-21T01:57:09.000    DOT             Department of Transportation
# 5   2022-03-21T01:56:46.000   NYPD          New York City Police Department
# 6   2022-03-21T01:55:36.000   NYPD          New York City Police Department
# 7   2022-03-21T01:53:53.000   NYPD          New York City Police Department
# 8   2022-03-21T01:53:18.000    DCA           Department of Consumer Affairs
# 9   2022-03-21T01:52:53.000   NYPD          New York City Police Department
# 10  2022-03-21T01:52:38.000   NYPD          New York City Police Department
# 11  2022-03-21T01:52:37.000   NYPD          New York City Police Department
# 12  2022-03-21T01:52:26.000   NYPD          New York City Police Department
# 13  2022-03-21T01:50:08.000  DOHMH  Department of Health and Mental Hygiene
# 14  2022-03-21T01:49:45.000   NYPD          New York City Police Department
# 15  2022-03-21T01:48:02.000   NYPD          New York City Police Department
# 16  2022-03-21T01:47:51.000   NYPD          New York City Police Department
# 17  2022-03-21T01:47:45.000   NYPD          New York City Police Department
# 18  2022-03-21T01:47:14.000   NYPD          New York City Police Department
# 19  2022-03-21T01:46:39.000   NYPD          New York City Police Department
# 20  2022-03-21T01:46:06.000   NYPD          New York City Police Department
# 21  2022-03-21T01:45:59.000   NYPD          New York City Police Department
# 22  2022-03-21T01:45:54.000   NYPD          New York City Police Department
# 23  2022-03-21T01:45:21.000   NYPD          New York City Police Department
# 24  2022-03-21T01:45:13.000   NYPD          New York City Police Department
#
#              complaint_type                     descriptor  \
# 0          Blocked Driveway                      No Access
# 1          Blocked Driveway                      No Access
# 2           Noise - Vehicle                  Engine Idling
# 3       Noise - Residential                Loud Television
# 4     Street Sign - Missing                  Other/Unknown
# 5       Noise - Residential                   Loud Talking
# 6           Noise - Vehicle                  Engine Idling
# 7       Noise - Residential                   Loud Talking
# 8        Consumer Complaint             Mobile Food Vendor
# 9           Noise - Vehicle                Car/Truck Music
# 10      Noise - Residential               Loud Music/Party
# 11          Illegal Parking    Parking Permit Improper Use
# 12      Noise - Residential               Loud Music/Party
# 13       Food Establishment         Kitchen/Food Prep Area
# 14  Noise - Street/Sidewalk               Loud Music/Party
# 15          Noise - Vehicle                  Engine Idling
# 16      Noise - Residential               Banging/Pounding
# 17       Noise - Commercial               Loud Music/Party
# 18      Noise - Residential               Banging/Pounding
# 19          Illegal Parking  Posted Parking Sign Violation
# 20         Blocked Driveway                      No Access
# 21       Noise - Commercial               Loud Music/Party
# 22      Noise - Residential               Loud Music/Party
# 23          Illegal Parking   Commercial Overnight Parking
# 24      Noise - Residential               Banging/Pounding
#
#                  location_type incident_zip       incident_address    borough
# 0              Street/Sidewalk        11207     2869 FULTON STREET   BROOKLYN
# 1              Street/Sidewalk        11207     2869 FULTON STREET   BROOKLYN
# 2              Street/Sidewalk        11373        92-01 51 AVENUE     QUEENS
# 3   Residential Building/House        10030   112 WEST  138 STREET  MANHATTAN
# 4                       Street        10029  1501 LEXINGTON AVENUE  MANHATTAN
# 5   Residential Building/House        10009   725 EAST    5 STREET  MANHATTAN
# 6              Street/Sidewalk        11419        ATLANTIC AVENUE     QUEENS
# 7   Residential Building/House        10039   271 WEST  146 STREET  MANHATTAN
# 8                     Business        10001   651 WEST   33 STREET  MANHATTAN
# 9              Street/Sidewalk        10456    1254 SHERMAN AVENUE      BRONX
# 10  Residential Building/House        11374          99-65 64 ROAD     QUEENS
# 11             Street/Sidewalk        11370        31-20 82 STREET     QUEENS
# 12  Residential Building/House        11213        86 UTICA AVENUE   BROOKLYN
# 13  Restaurant/Bar/Deli/Bakery        10010    64 WEST   22 STREET  MANHATTAN
# 14             Street/Sidewalk        10456    1254 SHERMAN AVENUE      BRONX
# 15             Street/Sidewalk        11101         2-01 51 AVENUE     QUEENS
# 16  Residential Building/House        10457  1880 VALENTINE AVENUE      BRONX
# 17         Club/Bar/Restaurant        11103  28-26 STEINWAY STREET     QUEENS
# 18  Residential Building/House        10451  890 COURTLANDT AVENUE      BRONX
# 19             Street/Sidewalk        11211       106 MARCY AVENUE   BROOKLYN
# 20             Street/Sidewalk        11355       132-46 41 AVENUE     QUEENS
# 21            Store/Commercial        10458     2645 BRIGGS AVENUE      BRONX
# 22  Residential Building/House        10040     11 HILLSIDE AVENUE  MANHATTAN
# 23             Street/Sidewalk        11235    117 BEAUMONT STREET   BROOKLYN
# 24  Residential Building/House        11372        35-43 84 STREET     QUEENS

# %%
cleaned_data = data_extractor(get_raw_data())

# %%
sql_create_cleaned_table = ''' CREATE TABLE calls(
                            id INTEGER PRIMARY KEY AUTOINCREMENT,
                            created_data text,
                            agency text,
                            agency_name text,
                            complaint_type text,
                            descriptor text,
                            location_type text,
                            location_zip text,
                            incident_zip text,
                            incident_address text,
                            borough text
)
'''

# %%
con = sqlite3.connect('calls.db')
cur = con.cursor()
cur.execute(sql_create_cleaned_table)
con.close()

# %%
# Takes list of dictionaries (result of data extractor) 
# Returns list of tuples, where tuples are the values from the dictionaries

def json_extractor(list_of_dicts):
    # Initialize a list that's going to hold all of my tuple pairs
    list_of_tuples = []
    # Iterate over the list of dictionaries
    for row in list_of_dicts:
        # Create a tuple of all values within that row
        temp_list = tuple(x for x in row.values())
        # Append the tuple to the list
        list_of_tuples.append(temp_list)
    return list_of_tuples

# %%
holder = json_extractor(cleaned_data)

# %%
con = sqlite3.connect('calls.db')
cur = con.cursor()
cur.executemany("INSERT INTO calls (created_data,agency,agency_name,complaint_type,descriptor,location_type,incident_zip,incident_address,borough) VALUES (?,?,?,?,?,?,?,?,?)",holder)
con.commit()
con.close()

# %%
con = sqlite3.connect('calls.db')
cur = con.cursor()
for row in cur.execute('select * from calls where borough=:x', {'x': 'QUEENS'}):
    print(row)
con.close()
# Out:
# (3, '2022-03-21T01:59:05.000', 'NYPD', 'New York City Police Department', 'Noise - Vehicle', 'Engine Idling', 'Street/Sidewalk', None, '11373', '92-01 51 AVENUE', 'QUEENS')
# (7, '2022-03-21T01:55:36.000', 'NYPD', 'New York City Police Department', 'Noise - Vehicle', 'Engine Idling', 'Street/Sidewalk', None, '11419', 'ATLANTIC AVENUE', 'QUEENS')
# (11, '2022-03-21T01:52:38.000', 'NYPD', 'New York City Police Department', 'Noise - Residential', 'Loud Music/Party', 'Residential Building/House', None, '11374', '99-65 64 ROAD', 'QUEENS')
# (12, '2022-03-21T01:52:37.000', 'NYPD', 'New York City Police Department', 'Illegal Parking', 'Parking Permit Improper Use', 'Street/Sidewalk', None, '11370', '31-20 82 STREET', 'QUEENS')
# (16, '2022-03-21T01:48:02.000', 'NYPD', 'New York City Police Department', 'Noise - Vehicle', 'Engine Idling', 'Street/Sidewalk', None, '11101', '2-01 51 AVENUE', 'QUEENS')
# (18, '2022-03-21T01:47:45.000', 'NYPD', 'New York City Police Department', 'Noise - Commercial', 'Loud Music/Party', 'Club/Bar/Restaurant', None, '11103', '28-26 STEINWAY STREET', 'QUEENS')
# (21, '2022-03-21T01:46:06.000', 'NYPD', 'New York City Police Department', 'Blocked Driveway', 'No Access', 'Street/Sidewalk', None, '11355', '132-46 41 AVENUE', 'QUEENS')
# (25, '2022-03-21T01:45:13.000', 'NYPD', 'New York City Police Department', 'Noise - Residential', 'Banging/Pounding', 'Residential Building/House', None, '11372', '35-43 84 STREET', 'QUEENS')

# %%
def return_rows_by_borough(borough_name):
    con = sqlite3.connect('calls.db')
    cur = con.cursor()
    dict_to_pass = {'x': borough_name}
    list_of_rows = [x for x in cur.execute('select * from calls where borough=:x', dict_to_pass)]
    con.close()
    if list_of_rows:
        return list_of_rows
    else:
        return 'No Matches Found'

# %%
return_rows_by_borough('QUEENS')
# Out:
# [(3,
#   '2022-03-21T01:59:05.000',
#   'NYPD',
#   'New York City Police Department',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   None,
#   '11373',
#   '92-01 51 AVENUE',
#   'QUEENS'),
#  (7,
#   '2022-03-21T01:55:36.000',
#   'NYPD',
#   'New York City Police Department',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   None,
#   '11419',
#   'ATLANTIC AVENUE',
#   'QUEENS'),
#  (11,
#   '2022-03-21T01:52:38.000',
#   'NYPD',
#   'New York City Police Department',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   None,
#   '11374',
#   '99-65 64 ROAD',
#   'QUEENS'),
#  (12,
#   '2022-03-21T01:52:37.000',
#   'NYPD',
#   'New York City Police Department',
#   'Illegal Parking',
#   'Parking Permit Improper Use',
#   'Street/Sidewalk',
#   None,
#   '11370',
#   '31-20 82 STREET',
#   'QUEENS'),
#  (16,
#   '2022-03-21T01:48:02.000',
#   'NYPD',
#   'New York City Police Department',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   None,
#   '11101',
#   '2-01 51 AVENUE',
#   'QUEENS'),
#  (18,
#   '2022-03-21T01:47:45.000',
#   'NYPD',
#   'New York City Police Department',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   None,
#   '11103',
#   '28-26 STEINWAY STREET',
#   'QUEENS'),
#  (21,
#   '2022-03-21T01:46:06.000',
#   'NYPD',
#   'New York City Police Department',
#   'Blocked Driveway',
#   'No Access',
#   'Street/Sidewalk',
#   None,
#   '11355',
#   '132-46 41 AVENUE',
#   'QUEENS'),
#  (25,
#   '2022-03-21T01:45:13.000',
#   'NYPD',
#   'New York City Police Department',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   None,
#   '11372',
#   '35-43 84 STREET',
#   'QUEENS')]

# %% [markdown]
# ## Machine Learning
#
# Software that understands patterns - repeated behavior, grouping
#
# Classification - Supervized learning - When you know the targeting value. We feed in the data to the computer
# Clustering - Unsupervized learning - when the target value is unknown.
#
# Two types of grouping: Classification & Clustering
# The process of giving stimulus to a machine and helping it learn through it’s mistakes in recognition
